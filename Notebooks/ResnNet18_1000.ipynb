# %% [markdown]
# # Font Classification with PyTorch and ResNet18
# In this notebook, we will use the PyTorch deep learning framework to train a ResNet18 model to classify fonts. We will use the `torchvision` library to load the dataset and the `sklearn` library to evaluate the model using accuracy, precision, recall, F1-score, and the ROC curve. We will also visualize the confusion matrix to understand the model's performance on each class.

# %% [markdown]
# Imports

# %%
import numpy as np
from torchvision import datasets, transforms
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import torch
from torchvision import models
from torch.utils.data import DataLoader
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import time

# %% [markdown]
# Choose a model

# %%
model_name = 'resnet18'
print(f'Using model: {model_name}')
# Out:
# Using model: resnet18

# %% [markdown]
# Load and prepare the dataset

# %%
image_height = 32
image_width = 150
train_size_perc = 0.7

# Set the seed for reproducibility
torch.manual_seed(0)

# Define transformations for preprocessing
transform = transforms.Compose([
    transforms.Resize((image_height, image_width)),  # Resize images to a fixed size
    transforms.ToTensor(),                           # Convert images to tensors
    transforms.Normalize(mean=[0.5, 0.5, 0.5],      # Normalize pixel values
                         std=[0.5, 0.5, 0.5])])

# Specify the path to your dataset
data_dir = '../fonts'

# Load the dataset using ImageFolder
dataset = datasets.ImageFolder(root=data_dir, transform=transform)

# Define the sizes of the training, validation, and test sets
train_size = int(train_size_perc * len(dataset))  # 70% of the dataset for training
val_size = int(((1.0 - train_size_perc)/2) * len(dataset))    # 15% for validation
test_size = len(dataset) - train_size - val_size  # Remaining for test (15%)

# Split the dataset into training, validation, and test sets
train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(
    dataset, [train_size, val_size, test_size])

batch_size = int(train_size * 0.01)

# Create data loaders for training, validation, and test sets
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Calculate the size of the dataset
num_images = len(dataset)
num_batches = len(train_loader)
print(f'Number of images: {num_images}')
print(f'Number of batches: {num_batches}')
print(f'Batch size: {batch_size}')
print(f'Number of training images: {len(train_dataset)}')
print(f'Number of validation images: {len(val_dataset)}')
print(f'Number of test images: {len(test_dataset)}')

# Get the class names
class_names = dataset.classes
print(f'Class names: {class_names}')
# Out:
# Number of images: 15000
# Number of batches: 100
# Batch size: 105
# Number of training images: 10500
# Number of validation images: 2250
# Number of test images: 2250
# Class names: ['Algerian', 'Arial', 'Baskerville', 'Calibry', 'Calligraphy', 'Cambria', 'Comic Sans MS', 'Courier', 'Elephant', 'Fascinate', 'Georgia', 'Helvetica', 'Lucida Bright', 'Nasalization', 'Times New Roman']

# %% [markdown]
# Load the model

# %%
from sys import platform

# Load the model
model = models.__dict__[model_name](weights=None)
num_ftrs = model.fc.in_features
model.fc = torch.nn.Linear(num_ftrs, len(class_names))

# Move model to the device (CPU or GPU)
if platform != "win32":
    device = torch.device('mps' if torch.backends.mps.is_available() else 'cpu')
else:
    device = torch.device('gpu' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
print(f'Model moved to {device}')
# Out:
# Model moved to mps

# %% [markdown]
# Train the model

# %%
# Define the loss function
criterion = torch.nn.CrossEntropyLoss()

# Define the optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 40
best_val_loss = float('inf')

# Lists to store training and validation metrics for plotting
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

# Set the model to training mode
model.train()

start_time = time.time()

for epoch in range(num_epochs):
    print(f'Epoch {epoch + 1}\n-------------------------------')
    # Training phase
    model.train()
    train_loss = 0.0
    correct_train = 0
    total_train = 0
    for i, (inputs, labels) in enumerate(train_loader):
        inputs = inputs.to(device)
        labels = labels.to(device)

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * inputs.size(0)
        
        # Calculate accuracy
        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

        # Print training statistics
        if (i + 1) % 10 == 0:
            print(f'Training - Epoch [{epoch + 1}/{num_epochs}], Step [{i + 1}/{len(train_loader)}], Loss: {loss.item():.4f}')

    # Calculate average training loss and accuracy
    train_loss /= len(train_loader.dataset)
    train_accuracy = correct_train / total_train
    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)
    
    # Validation phase
    model.eval()
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(val_loader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            val_loss += loss.item() * inputs.size(0)

            # Calculate accuracy
            _, predicted = torch.max(outputs, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    # Print validation statistics
    val_loss /= len(val_loader.dataset)
    val_accuracy = correct_val / total_val
    val_losses.append(val_loss)
    val_accuracies.append(val_accuracy)
    print(f'Validation - Epoch [{epoch + 1}/{num_epochs}], Loss: {val_loss:.4f}, Accuracy: {val_accuracy:.4f}')

    # Save the model if validation loss decreases
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), '../models/' + f'{model_name}_font_classifier.pth')
        print(f'Model saved as {model_name}_font_classifier.pth')

end_time = time.time()

# Plotting
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), train_losses, label='Training Loss')
plt.plot(range(1, num_epochs + 1), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), train_accuracies, label='Training Accuracy')
plt.plot(range(1, num_epochs + 1), val_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

print('Finished Training')

# Print the time taken for training
print(f'Time taken for training: {end_time - start_time:.2f} seconds')
## Print medium time per epoch
print(f'Medium time per epoch: {(end_time - start_time)/num_epochs:.2f} seconds')
# Out:
# Epoch 1
# -------------------------------
# Training - Epoch [1/40], Step [10/100], Loss: 1.5077
# Training - Epoch [1/40], Step [20/100], Loss: 0.8897
# Training - Epoch [1/40], Step [30/100], Loss: 0.5380
# Training - Epoch [1/40], Step [40/100], Loss: 0.3409
# Training - Epoch [1/40], Step [50/100], Loss: 0.3299
# Training - Epoch [1/40], Step [60/100], Loss: 0.4474
# Training - Epoch [1/40], Step [70/100], Loss: 0.3824
# Training - Epoch [1/40], Step [80/100], Loss: 0.2659
# Training - Epoch [1/40], Step [90/100], Loss: 0.1982
# Training - Epoch [1/40], Step [100/100], Loss: 0.0927
# Validation - Epoch [1/40], Loss: 0.8194, Accuracy: 0.7760
# Model saved as resnet18_font_classifier.pth
# Epoch 2
# -------------------------------
# Training - Epoch [2/40], Step [10/100], Loss: 0.1843
# Training - Epoch [2/40], Step [20/100], Loss: 0.1394
# Training - Epoch [2/40], Step [30/100], Loss: 0.3420
# Training - Epoch [2/40], Step [40/100], Loss: 0.1840
# Training - Epoch [2/40], Step [50/100], Loss: 0.2690
# Training - Epoch [2/40], Step [60/100], Loss: 0.1468
# Training - Epoch [2/40], Step [70/100], Loss: 0.1503
# Training - Epoch [2/40], Step [80/100], Loss: 0.1759
# Training - Epoch [2/40], Step [90/100], Loss: 0.0880
# Training - Epoch [2/40], Step [100/100], Loss: 0.1164
# Validation - Epoch [2/40], Loss: 0.9415, Accuracy: 0.7218
# Epoch 3
# -------------------------------
# Training - Epoch [3/40], Step [10/100], Loss: 0.1048
# Training - Epoch [3/40], Step [20/100], Loss: 0.0929
# Training - Epoch [3/40], Step [30/100], Loss: 0.0543
# Training - Epoch [3/40], Step [40/100], Loss: 0.0473
# Training - Epoch [3/40], Step [50/100], Loss: 0.0896
# Training - Epoch [3/40], Step [60/100], Loss: 0.0253
# Training - Epoch [3/40], Step [70/100], Loss: 0.0721
# Training - Epoch [3/40], Step [80/100], Loss: 0.1321
# Training - Epoch [3/40], Step [90/100], Loss: 0.0870
# Training - Epoch [3/40], Step [100/100], Loss: 0.0503
# Validation - Epoch [3/40], Loss: 0.2751, Accuracy: 0.9236
# Model saved as resnet18_font_classifier.pth
# Epoch 4
# -------------------------------
# Training - Epoch [4/40], Step [10/100], Loss: 0.0323
# Training - Epoch [4/40], Step [20/100], Loss: 0.0616
# Training - Epoch [4/40], Step [30/100], Loss: 0.0482
# Training - Epoch [4/40], Step [40/100], Loss: 0.0319
# Training - Epoch [4/40], Step [50/100], Loss: 0.0069
# Training - Epoch [4/40], Step [60/100], Loss: 0.1156
# Training - Epoch [4/40], Step [70/100], Loss: 0.0587
# Training - Epoch [4/40], Step [80/100], Loss: 0.0779
# Training - Epoch [4/40], Step [90/100], Loss: 0.0722
# Training - Epoch [4/40], Step [100/100], Loss: 0.1569
# Validation - Epoch [4/40], Loss: 0.3605, Accuracy: 0.9107
# Epoch 5
# -------------------------------
# Training - Epoch [5/40], Step [10/100], Loss: 0.0859
# Training - Epoch [5/40], Step [20/100], Loss: 0.0784
# Training - Epoch [5/40], Step [30/100], Loss: 0.0282
# Training - Epoch [5/40], Step [40/100], Loss: 0.0489
# Training - Epoch [5/40], Step [50/100], Loss: 0.1102
# Training - Epoch [5/40], Step [60/100], Loss: 0.0515
# Training - Epoch [5/40], Step [70/100], Loss: 0.0163
# Training - Epoch [5/40], Step [80/100], Loss: 0.0600
# Training - Epoch [5/40], Step [90/100], Loss: 0.0094
# Training - Epoch [5/40], Step [100/100], Loss: 0.0400
# Validation - Epoch [5/40], Loss: 0.0772, Accuracy: 0.9773
# Model saved as resnet18_font_classifier.pth
# Epoch 6
# -------------------------------
# Training - Epoch [6/40], Step [10/100], Loss: 0.0186
# Training - Epoch [6/40], Step [20/100], Loss: 0.0079
# Training - Epoch [6/40], Step [30/100], Loss: 0.0516
# Training - Epoch [6/40], Step [40/100], Loss: 0.0645
# Training - Epoch [6/40], Step [50/100], Loss: 0.0629
# Training - Epoch [6/40], Step [60/100], Loss: 0.0563
# Training - Epoch [6/40], Step [70/100], Loss: 0.0287
# Training - Epoch [6/40], Step [80/100], Loss: 0.0024
# Training - Epoch [6/40], Step [90/100], Loss: 0.0437
# Training - Epoch [6/40], Step [100/100], Loss: 0.1134
# Validation - Epoch [6/40], Loss: 0.0966, Accuracy: 0.9707
# Epoch 7
# -------------------------------
# Training - Epoch [7/40], Step [10/100], Loss: 0.0902
# Training - Epoch [7/40], Step [20/100], Loss: 0.0463
# Training - Epoch [7/40], Step [30/100], Loss: 0.0195
# Training - Epoch [7/40], Step [40/100], Loss: 0.0567
# Training - Epoch [7/40], Step [50/100], Loss: 0.0717
# Training - Epoch [7/40], Step [60/100], Loss: 0.0843
# Training - Epoch [7/40], Step [70/100], Loss: 0.0633
# Training - Epoch [7/40], Step [80/100], Loss: 0.0071
# Training - Epoch [7/40], Step [90/100], Loss: 0.0482
# Training - Epoch [7/40], Step [100/100], Loss: 0.0179
# Validation - Epoch [7/40], Loss: 0.2518, Accuracy: 0.9369
# Epoch 8
# -------------------------------
# Training - Epoch [8/40], Step [10/100], Loss: 0.1117
# Training - Epoch [8/40], Step [20/100], Loss: 0.0940
# Training - Epoch [8/40], Step [30/100], Loss: 0.0348
# Training - Epoch [8/40], Step [40/100], Loss: 0.0489
# Training - Epoch [8/40], Step [50/100], Loss: 0.0089
# Training - Epoch [8/40], Step [60/100], Loss: 0.0524
# Training - Epoch [8/40], Step [70/100], Loss: 0.0619
# Training - Epoch [8/40], Step [80/100], Loss: 0.0517
# Training - Epoch [8/40], Step [90/100], Loss: 0.0978
# Training - Epoch [8/40], Step [100/100], Loss: 0.0055
# Validation - Epoch [8/40], Loss: 0.0871, Accuracy: 0.9720
# Epoch 9
# -------------------------------
# Training - Epoch [9/40], Step [10/100], Loss: 0.0085
# Training - Epoch [9/40], Step [20/100], Loss: 0.1056
# Training - Epoch [9/40], Step [30/100], Loss: 0.0123
# Training - Epoch [9/40], Step [40/100], Loss: 0.0274
# Training - Epoch [9/40], Step [50/100], Loss: 0.0352
# Training - Epoch [9/40], Step [60/100], Loss: 0.0122
# Training - Epoch [9/40], Step [70/100], Loss: 0.0239
# Training - Epoch [9/40], Step [80/100], Loss: 0.0143
# Training - Epoch [9/40], Step [90/100], Loss: 0.0181
# Training - Epoch [9/40], Step [100/100], Loss: 0.0011
# Validation - Epoch [9/40], Loss: 0.2526, Accuracy: 0.9373
# Epoch 10
# -------------------------------
# Training - Epoch [10/40], Step [10/100], Loss: 0.0177
# Training - Epoch [10/40], Step [20/100], Loss: 0.0397
# Training - Epoch [10/40], Step [30/100], Loss: 0.0285
# Training - Epoch [10/40], Step [40/100], Loss: 0.1599
# Training - Epoch [10/40], Step [50/100], Loss: 0.0019
# Training - Epoch [10/40], Step [60/100], Loss: 0.0115
# Training - Epoch [10/40], Step [70/100], Loss: 0.0061
# Training - Epoch [10/40], Step [80/100], Loss: 0.1284
# Training - Epoch [10/40], Step [90/100], Loss: 0.0096
# Training - Epoch [10/40], Step [100/100], Loss: 0.0416
# Validation - Epoch [10/40], Loss: 0.1459, Accuracy: 0.9658
# Epoch 11
# -------------------------------
# Training - Epoch [11/40], Step [10/100], Loss: 0.0247
# Training - Epoch [11/40], Step [20/100], Loss: 0.0316
# Training - Epoch [11/40], Step [30/100], Loss: 0.0287
# Training - Epoch [11/40], Step [40/100], Loss: 0.0038
# Training - Epoch [11/40], Step [50/100], Loss: 0.0332
# Training - Epoch [11/40], Step [60/100], Loss: 0.0060
# Training - Epoch [11/40], Step [70/100], Loss: 0.0104
# Training - Epoch [11/40], Step [80/100], Loss: 0.0476
# Training - Epoch [11/40], Step [90/100], Loss: 0.0021
# Training - Epoch [11/40], Step [100/100], Loss: 0.0764
# Validation - Epoch [11/40], Loss: 0.0619, Accuracy: 0.9796
# Model saved as resnet18_font_classifier.pth
# Epoch 12
# -------------------------------
# Training - Epoch [12/40], Step [10/100], Loss: 0.0118
# Training - Epoch [12/40], Step [20/100], Loss: 0.0297
# Training - Epoch [12/40], Step [30/100], Loss: 0.0466
# Training - Epoch [12/40], Step [40/100], Loss: 0.0452
# Training - Epoch [12/40], Step [50/100], Loss: 0.0023
# Training - Epoch [12/40], Step [60/100], Loss: 0.0006
# Training - Epoch [12/40], Step [70/100], Loss: 0.0375
# Training - Epoch [12/40], Step [80/100], Loss: 0.0146
# Training - Epoch [12/40], Step [90/100], Loss: 0.1059
# Training - Epoch [12/40], Step [100/100], Loss: 0.0436
# Validation - Epoch [12/40], Loss: 0.1068, Accuracy: 0.9662
# Epoch 13
# -------------------------------
# Training - Epoch [13/40], Step [10/100], Loss: 0.0256
# Training - Epoch [13/40], Step [20/100], Loss: 0.0489
# Training - Epoch [13/40], Step [30/100], Loss: 0.0144
# Training - Epoch [13/40], Step [40/100], Loss: 0.0064
# Training - Epoch [13/40], Step [50/100], Loss: 0.0321
# Training - Epoch [13/40], Step [60/100], Loss: 0.0097
# Training - Epoch [13/40], Step [70/100], Loss: 0.0221
# Training - Epoch [13/40], Step [80/100], Loss: 0.0013
# Training - Epoch [13/40], Step [90/100], Loss: 0.0182
# Training - Epoch [13/40], Step [100/100], Loss: 0.1339
# Validation - Epoch [13/40], Loss: 0.2105, Accuracy: 0.9427
# Epoch 14
# -------------------------------
# Training - Epoch [14/40], Step [10/100], Loss: 0.0035
# Training - Epoch [14/40], Step [20/100], Loss: 0.0280
# Training - Epoch [14/40], Step [30/100], Loss: 0.0418
# Training - Epoch [14/40], Step [40/100], Loss: 0.0080
# Training - Epoch [14/40], Step [50/100], Loss: 0.0199
# Training - Epoch [14/40], Step [60/100], Loss: 0.0047
# Training - Epoch [14/40], Step [70/100], Loss: 0.0158
# Training - Epoch [14/40], Step [80/100], Loss: 0.0104
# Training - Epoch [14/40], Step [90/100], Loss: 0.0051
# Training - Epoch [14/40], Step [100/100], Loss: 0.0080
# Validation - Epoch [14/40], Loss: 0.0586, Accuracy: 0.9836
# Model saved as resnet18_font_classifier.pth
# Epoch 15
# -------------------------------
# Training - Epoch [15/40], Step [10/100], Loss: 0.0057
# Training - Epoch [15/40], Step [20/100], Loss: 0.0202
# Training - Epoch [15/40], Step [30/100], Loss: 0.0095
# Training - Epoch [15/40], Step [40/100], Loss: 0.0358
# Training - Epoch [15/40], Step [50/100], Loss: 0.0111
# Training - Epoch [15/40], Step [60/100], Loss: 0.0380
# Training - Epoch [15/40], Step [70/100], Loss: 0.0331
# Training - Epoch [15/40], Step [80/100], Loss: 0.0626
# Training - Epoch [15/40], Step [90/100], Loss: 0.0007
# Training - Epoch [15/40], Step [100/100], Loss: 0.0084
# Validation - Epoch [15/40], Loss: 0.0763, Accuracy: 0.9769
# Epoch 16
# -------------------------------
# Training - Epoch [16/40], Step [10/100], Loss: 0.0047
# Training - Epoch [16/40], Step [20/100], Loss: 0.0032
# Training - Epoch [16/40], Step [30/100], Loss: 0.0045
# Training - Epoch [16/40], Step [40/100], Loss: 0.0141
# Training - Epoch [16/40], Step [50/100], Loss: 0.0490
# Training - Epoch [16/40], Step [60/100], Loss: 0.0630
# Training - Epoch [16/40], Step [70/100], Loss: 0.0052
# Training - Epoch [16/40], Step [80/100], Loss: 0.0281
# Training - Epoch [16/40], Step [90/100], Loss: 0.0376
# Training - Epoch [16/40], Step [100/100], Loss: 0.0425
# Validation - Epoch [16/40], Loss: 0.0802, Accuracy: 0.9738
# Epoch 17
# -------------------------------
# Training - Epoch [17/40], Step [10/100], Loss: 0.0396
# Training - Epoch [17/40], Step [20/100], Loss: 0.2027
# Training - Epoch [17/40], Step [30/100], Loss: 0.0594
# Training - Epoch [17/40], Step [40/100], Loss: 0.0044
# Training - Epoch [17/40], Step [50/100], Loss: 0.1910
# Training - Epoch [17/40], Step [60/100], Loss: 0.0534
# Training - Epoch [17/40], Step [70/100], Loss: 0.0978
# Training - Epoch [17/40], Step [80/100], Loss: 0.0310
# Training - Epoch [17/40], Step [90/100], Loss: 0.0289
# Training - Epoch [17/40], Step [100/100], Loss: 0.0471
# Validation - Epoch [17/40], Loss: 0.0632, Accuracy: 0.9809
# Epoch 18
# -------------------------------
# Training - Epoch [18/40], Step [10/100], Loss: 0.0083
# Training - Epoch [18/40], Step [20/100], Loss: 0.0014
# Training - Epoch [18/40], Step [30/100], Loss: 0.0100
# Training - Epoch [18/40], Step [40/100], Loss: 0.0008
# Training - Epoch [18/40], Step [50/100], Loss: 0.0014
# Training - Epoch [18/40], Step [60/100], Loss: 0.0182
# Training - Epoch [18/40], Step [70/100], Loss: 0.0021
# Training - Epoch [18/40], Step [80/100], Loss: 0.0007
# Training - Epoch [18/40], Step [90/100], Loss: 0.0151
# Training - Epoch [18/40], Step [100/100], Loss: 0.0234
# Validation - Epoch [18/40], Loss: 0.2374, Accuracy: 0.9440
# Epoch 19
# -------------------------------
# Training - Epoch [19/40], Step [10/100], Loss: 0.0195
# Training - Epoch [19/40], Step [20/100], Loss: 0.0106
# Training - Epoch [19/40], Step [30/100], Loss: 0.0676
# Training - Epoch [19/40], Step [40/100], Loss: 0.0017
# Training - Epoch [19/40], Step [50/100], Loss: 0.0030
# Training - Epoch [19/40], Step [60/100], Loss: 0.0905
# Training - Epoch [19/40], Step [70/100], Loss: 0.0302
# Training - Epoch [19/40], Step [80/100], Loss: 0.0167
# Training - Epoch [19/40], Step [90/100], Loss: 0.0035
# Training - Epoch [19/40], Step [100/100], Loss: 0.0028
# Validation - Epoch [19/40], Loss: 0.0673, Accuracy: 0.9791
# Epoch 20
# -------------------------------
# Training - Epoch [20/40], Step [10/100], Loss: 0.0019
# Training - Epoch [20/40], Step [20/100], Loss: 0.0937
# Training - Epoch [20/40], Step [30/100], Loss: 0.0224
# Training - Epoch [20/40], Step [40/100], Loss: 0.0011
# Training - Epoch [20/40], Step [50/100], Loss: 0.0031
# Training - Epoch [20/40], Step [60/100], Loss: 0.0066
# Training - Epoch [20/40], Step [70/100], Loss: 0.0038
# Training - Epoch [20/40], Step [80/100], Loss: 0.0005
# Training - Epoch [20/40], Step [90/100], Loss: 0.0011
# Training - Epoch [20/40], Step [100/100], Loss: 0.0007
# Validation - Epoch [20/40], Loss: 0.0567, Accuracy: 0.9849
# Model saved as resnet18_font_classifier.pth
# Epoch 21
# -------------------------------
# Training - Epoch [21/40], Step [10/100], Loss: 0.0057
# Training - Epoch [21/40], Step [20/100], Loss: 0.0016
# Training - Epoch [21/40], Step [30/100], Loss: 0.0151
# Training - Epoch [21/40], Step [40/100], Loss: 0.0051
# Training - Epoch [21/40], Step [50/100], Loss: 0.0228
# Training - Epoch [21/40], Step [60/100], Loss: 0.0096
# Training - Epoch [21/40], Step [70/100], Loss: 0.0080
# Training - Epoch [21/40], Step [80/100], Loss: 0.0179
# Training - Epoch [21/40], Step [90/100], Loss: 0.0012
# Training - Epoch [21/40], Step [100/100], Loss: 0.0017
# Validation - Epoch [21/40], Loss: 0.0334, Accuracy: 0.9902
# Model saved as resnet18_font_classifier.pth
# Epoch 22
# -------------------------------
# Training - Epoch [22/40], Step [10/100], Loss: 0.0014
# Training - Epoch [22/40], Step [20/100], Loss: 0.0005
# Training - Epoch [22/40], Step [30/100], Loss: 0.0049
# Training - Epoch [22/40], Step [40/100], Loss: 0.0011
# Training - Epoch [22/40], Step [50/100], Loss: 0.0003
# Training - Epoch [22/40], Step [60/100], Loss: 0.0077
# Training - Epoch [22/40], Step [70/100], Loss: 0.0010
# Training - Epoch [22/40], Step [80/100], Loss: 0.0005
# Training - Epoch [22/40], Step [90/100], Loss: 0.0168
# Training - Epoch [22/40], Step [100/100], Loss: 0.0026
# Validation - Epoch [22/40], Loss: 0.0699, Accuracy: 0.9818
# Epoch 23
# -------------------------------
# Training - Epoch [23/40], Step [10/100], Loss: 0.0015
# Training - Epoch [23/40], Step [20/100], Loss: 0.0494
# Training - Epoch [23/40], Step [30/100], Loss: 0.0162
# Training - Epoch [23/40], Step [40/100], Loss: 0.0171
# Training - Epoch [23/40], Step [50/100], Loss: 0.0343
# Training - Epoch [23/40], Step [60/100], Loss: 0.0182
# Training - Epoch [23/40], Step [70/100], Loss: 0.0183
# Training - Epoch [23/40], Step [80/100], Loss: 0.0335
# Training - Epoch [23/40], Step [90/100], Loss: 0.0576
# Training - Epoch [23/40], Step [100/100], Loss: 0.4545
# Validation - Epoch [23/40], Loss: 0.3024, Accuracy: 0.9342
# Epoch 24
# -------------------------------
# Training - Epoch [24/40], Step [10/100], Loss: 0.0287
# Training - Epoch [24/40], Step [20/100], Loss: 0.0977
# Training - Epoch [24/40], Step [30/100], Loss: 0.0137
# Training - Epoch [24/40], Step [40/100], Loss: 0.0151
# Training - Epoch [24/40], Step [50/100], Loss: 0.0947
# Training - Epoch [24/40], Step [60/100], Loss: 0.0814
# Training - Epoch [24/40], Step [70/100], Loss: 0.0190
# Training - Epoch [24/40], Step [80/100], Loss: 0.0030
# Training - Epoch [24/40], Step [90/100], Loss: 0.0633
# Training - Epoch [24/40], Step [100/100], Loss: 0.0477
# Validation - Epoch [24/40], Loss: 0.1952, Accuracy: 0.9502
# Epoch 25
# -------------------------------
# Training - Epoch [25/40], Step [10/100], Loss: 0.0051
# Training - Epoch [25/40], Step [20/100], Loss: 0.1123
# Training - Epoch [25/40], Step [30/100], Loss: 0.0301
# Training - Epoch [25/40], Step [40/100], Loss: 0.0336
# Training - Epoch [25/40], Step [50/100], Loss: 0.0042
# Training - Epoch [25/40], Step [60/100], Loss: 0.0022
# Training - Epoch [25/40], Step [70/100], Loss: 0.0117
# Training - Epoch [25/40], Step [80/100], Loss: 0.0215
# Training - Epoch [25/40], Step [90/100], Loss: 0.0002
# Training - Epoch [25/40], Step [100/100], Loss: 0.0015
# Validation - Epoch [25/40], Loss: 0.1129, Accuracy: 0.9689
# Epoch 26
# -------------------------------
# Training - Epoch [26/40], Step [10/100], Loss: 0.0717
# Training - Epoch [26/40], Step [20/100], Loss: 0.0232
# Training - Epoch [26/40], Step [30/100], Loss: 0.0029
# Training - Epoch [26/40], Step [40/100], Loss: 0.0009
# Training - Epoch [26/40], Step [50/100], Loss: 0.0247
# Training - Epoch [26/40], Step [60/100], Loss: 0.0132
# Training - Epoch [26/40], Step [70/100], Loss: 0.0096
# Training - Epoch [26/40], Step [80/100], Loss: 0.0418
# Training - Epoch [26/40], Step [90/100], Loss: 0.0035
# Training - Epoch [26/40], Step [100/100], Loss: 0.0870
# Validation - Epoch [26/40], Loss: 0.0691, Accuracy: 0.9831
# Epoch 27
# -------------------------------
# Training - Epoch [27/40], Step [10/100], Loss: 0.0051
# Training - Epoch [27/40], Step [20/100], Loss: 0.0106
# Training - Epoch [27/40], Step [30/100], Loss: 0.0317
# Training - Epoch [27/40], Step [40/100], Loss: 0.0653
# Training - Epoch [27/40], Step [50/100], Loss: 0.0101
# Training - Epoch [27/40], Step [60/100], Loss: 0.0044
# Training - Epoch [27/40], Step [70/100], Loss: 0.0423
# Training - Epoch [27/40], Step [80/100], Loss: 0.0046
# Training - Epoch [27/40], Step [90/100], Loss: 0.0178
# Training - Epoch [27/40], Step [100/100], Loss: 0.0038
# Validation - Epoch [27/40], Loss: 0.0421, Accuracy: 0.9880
# Epoch 28
# -------------------------------
# Training - Epoch [28/40], Step [10/100], Loss: 0.0025
# Training - Epoch [28/40], Step [20/100], Loss: 0.0039
# Training - Epoch [28/40], Step [30/100], Loss: 0.0004
# Training - Epoch [28/40], Step [40/100], Loss: 0.0017
# Training - Epoch [28/40], Step [50/100], Loss: 0.0001
# Training - Epoch [28/40], Step [60/100], Loss: 0.0071
# Training - Epoch [28/40], Step [70/100], Loss: 0.0006
# Training - Epoch [28/40], Step [80/100], Loss: 0.0037
# Training - Epoch [28/40], Step [90/100], Loss: 0.0017
# Training - Epoch [28/40], Step [100/100], Loss: 0.0002
# Validation - Epoch [28/40], Loss: 0.0837, Accuracy: 0.9791
# Epoch 29
# -------------------------------
# Training - Epoch [29/40], Step [10/100], Loss: 0.0020
# Training - Epoch [29/40], Step [20/100], Loss: 0.0089
# Training - Epoch [29/40], Step [30/100], Loss: 0.0027
# Training - Epoch [29/40], Step [40/100], Loss: 0.0038
# Training - Epoch [29/40], Step [50/100], Loss: 0.0001
# Training - Epoch [29/40], Step [60/100], Loss: 0.0003
# Training - Epoch [29/40], Step [70/100], Loss: 0.0002
# Training - Epoch [29/40], Step [80/100], Loss: 0.0001
# Training - Epoch [29/40], Step [90/100], Loss: 0.0029
# Training - Epoch [29/40], Step [100/100], Loss: 0.0015
# Validation - Epoch [29/40], Loss: 0.0245, Accuracy: 0.9916
# Model saved as resnet18_font_classifier.pth
# Epoch 30
# -------------------------------
# Training - Epoch [30/40], Step [10/100], Loss: 0.0002
# Training - Epoch [30/40], Step [20/100], Loss: 0.0001
# Training - Epoch [30/40], Step [30/100], Loss: 0.0003
# Training - Epoch [30/40], Step [40/100], Loss: 0.0007
# Training - Epoch [30/40], Step [50/100], Loss: 0.0046
# Training - Epoch [30/40], Step [60/100], Loss: 0.0001
# Training - Epoch [30/40], Step [70/100], Loss: 0.0008
# Training - Epoch [30/40], Step [80/100], Loss: 0.0012
# Training - Epoch [30/40], Step [90/100], Loss: 0.0002
# Training - Epoch [30/40], Step [100/100], Loss: 0.0007
# Validation - Epoch [30/40], Loss: 0.0226, Accuracy: 0.9938
# Model saved as resnet18_font_classifier.pth
# Epoch 31
# -------------------------------
# Training - Epoch [31/40], Step [10/100], Loss: 0.0014
# Training - Epoch [31/40], Step [20/100], Loss: 0.0009
# Training - Epoch [31/40], Step [30/100], Loss: 0.0003
# Training - Epoch [31/40], Step [40/100], Loss: 0.0003
# Training - Epoch [31/40], Step [50/100], Loss: 0.0496
# Training - Epoch [31/40], Step [60/100], Loss: 0.0012
# Training - Epoch [31/40], Step [70/100], Loss: 0.0004
# Training - Epoch [31/40], Step [80/100], Loss: 0.0009
# Training - Epoch [31/40], Step [90/100], Loss: 0.0002
# Training - Epoch [31/40], Step [100/100], Loss: 0.0111
# Validation - Epoch [31/40], Loss: 0.0252, Accuracy: 0.9929
# Epoch 32
# -------------------------------
# Training - Epoch [32/40], Step [10/100], Loss: 0.0000
# Training - Epoch [32/40], Step [20/100], Loss: 0.0005
# Training - Epoch [32/40], Step [30/100], Loss: 0.0011
# Training - Epoch [32/40], Step [40/100], Loss: 0.0018
# Training - Epoch [32/40], Step [50/100], Loss: 0.0003
# Training - Epoch [32/40], Step [60/100], Loss: 0.0016
# Training - Epoch [32/40], Step [70/100], Loss: 0.0094
# Training - Epoch [32/40], Step [80/100], Loss: 0.0009
# Training - Epoch [32/40], Step [90/100], Loss: 0.0010
# Training - Epoch [32/40], Step [100/100], Loss: 0.0018
# Validation - Epoch [32/40], Loss: 0.0494, Accuracy: 0.9880
# Epoch 33
# -------------------------------
# Training - Epoch [33/40], Step [10/100], Loss: 0.0043
# Training - Epoch [33/40], Step [20/100], Loss: 0.0001
# Training - Epoch [33/40], Step [30/100], Loss: 0.0023
# Training - Epoch [33/40], Step [40/100], Loss: 0.0103
# Training - Epoch [33/40], Step [50/100], Loss: 0.0033
# Training - Epoch [33/40], Step [60/100], Loss: 0.0026
# Training - Epoch [33/40], Step [70/100], Loss: 0.0275
# Training - Epoch [33/40], Step [80/100], Loss: 0.0218
# Training - Epoch [33/40], Step [90/100], Loss: 0.1134
# Training - Epoch [33/40], Step [100/100], Loss: 0.0295
# Validation - Epoch [33/40], Loss: 0.4964, Accuracy: 0.9080
# Epoch 34
# -------------------------------
# Training - Epoch [34/40], Step [10/100], Loss: 0.0852
# Training - Epoch [34/40], Step [20/100], Loss: 0.0836
# Training - Epoch [34/40], Step [30/100], Loss: 0.2767
# Training - Epoch [34/40], Step [40/100], Loss: 0.1063
# Training - Epoch [34/40], Step [50/100], Loss: 0.0417
# Training - Epoch [34/40], Step [60/100], Loss: 0.0342
# Training - Epoch [34/40], Step [70/100], Loss: 0.0298
# Training - Epoch [34/40], Step [80/100], Loss: 0.0123
# Training - Epoch [34/40], Step [90/100], Loss: 0.0022
# Training - Epoch [34/40], Step [100/100], Loss: 0.0166
# Validation - Epoch [34/40], Loss: 0.0759, Accuracy: 0.9796
# Epoch 35
# -------------------------------
# Training - Epoch [35/40], Step [10/100], Loss: 0.0017
# Training - Epoch [35/40], Step [20/100], Loss: 0.0571
# Training - Epoch [35/40], Step [30/100], Loss: 0.0193
# Training - Epoch [35/40], Step [40/100], Loss: 0.0382
# Training - Epoch [35/40], Step [50/100], Loss: 0.0032
# Training - Epoch [35/40], Step [60/100], Loss: 0.0242
# Training - Epoch [35/40], Step [70/100], Loss: 0.0046
# Training - Epoch [35/40], Step [80/100], Loss: 0.0003
# Training - Epoch [35/40], Step [90/100], Loss: 0.0030
# Training - Epoch [35/40], Step [100/100], Loss: 0.0208
# Validation - Epoch [35/40], Loss: 0.0359, Accuracy: 0.9880
# Epoch 36
# -------------------------------
# Training - Epoch [36/40], Step [10/100], Loss: 0.0018
# Training - Epoch [36/40], Step [20/100], Loss: 0.0022
# Training - Epoch [36/40], Step [30/100], Loss: 0.0003
# Training - Epoch [36/40], Step [40/100], Loss: 0.0022
# Training - Epoch [36/40], Step [50/100], Loss: 0.0006
# Training - Epoch [36/40], Step [60/100], Loss: 0.0020
# Training - Epoch [36/40], Step [70/100], Loss: 0.0006
# Training - Epoch [36/40], Step [80/100], Loss: 0.0560
# Training - Epoch [36/40], Step [90/100], Loss: 0.0047
# Training - Epoch [36/40], Step [100/100], Loss: 0.0018
# Validation - Epoch [36/40], Loss: 0.0624, Accuracy: 0.9853
# Epoch 37
# -------------------------------
# Training - Epoch [37/40], Step [10/100], Loss: 0.0007
# Training - Epoch [37/40], Step [20/100], Loss: 0.0005
# Training - Epoch [37/40], Step [30/100], Loss: 0.0037
# Training - Epoch [37/40], Step [40/100], Loss: 0.0012
# Training - Epoch [37/40], Step [50/100], Loss: 0.0012
# Training - Epoch [37/40], Step [60/100], Loss: 0.0009
# Training - Epoch [37/40], Step [70/100], Loss: 0.0003
# Training - Epoch [37/40], Step [80/100], Loss: 0.0025
# Training - Epoch [37/40], Step [90/100], Loss: 0.0015
# Training - Epoch [37/40], Step [100/100], Loss: 0.0042
# Validation - Epoch [37/40], Loss: 0.0468, Accuracy: 0.9889
# Epoch 38
# -------------------------------
# Training - Epoch [38/40], Step [10/100], Loss: 0.0036
# Training - Epoch [38/40], Step [20/100], Loss: 0.0001
# Training - Epoch [38/40], Step [30/100], Loss: 0.0150
# Training - Epoch [38/40], Step [40/100], Loss: 0.0142
# Training - Epoch [38/40], Step [50/100], Loss: 0.0314
# Training - Epoch [38/40], Step [60/100], Loss: 0.0014
# Training - Epoch [38/40], Step [70/100], Loss: 0.0014
# Training - Epoch [38/40], Step [80/100], Loss: 0.0014
# Training - Epoch [38/40], Step [90/100], Loss: 0.0001
# Training - Epoch [38/40], Step [100/100], Loss: 0.0017
# Validation - Epoch [38/40], Loss: 0.0729, Accuracy: 0.9796
# Epoch 39
# -------------------------------
# Training - Epoch [39/40], Step [10/100], Loss: 0.0028
# Training - Epoch [39/40], Step [20/100], Loss: 0.0149
# Training - Epoch [39/40], Step [30/100], Loss: 0.0219
# Training - Epoch [39/40], Step [40/100], Loss: 0.0358
# Training - Epoch [39/40], Step [50/100], Loss: 0.0023
# Training - Epoch [39/40], Step [60/100], Loss: 0.1027
# Training - Epoch [39/40], Step [70/100], Loss: 0.0570
# Training - Epoch [39/40], Step [80/100], Loss: 0.0109
# Training - Epoch [39/40], Step [90/100], Loss: 0.0039
# Training - Epoch [39/40], Step [100/100], Loss: 0.0199
# Validation - Epoch [39/40], Loss: 0.0808, Accuracy: 0.9742
# Epoch 40
# -------------------------------
# Training - Epoch [40/40], Step [10/100], Loss: 0.0123
# Training - Epoch [40/40], Step [20/100], Loss: 0.0186
# Training - Epoch [40/40], Step [30/100], Loss: 0.0135
# Training - Epoch [40/40], Step [40/100], Loss: 0.0046
# Training - Epoch [40/40], Step [50/100], Loss: 0.0031
# Training - Epoch [40/40], Step [60/100], Loss: 0.0273
# Training - Epoch [40/40], Step [70/100], Loss: 0.0012
# Training - Epoch [40/40], Step [80/100], Loss: 0.0022
# Training - Epoch [40/40], Step [90/100], Loss: 0.0009
# Training - Epoch [40/40], Step [100/100], Loss: 0.0029
# Validation - Epoch [40/40], Loss: 0.0636, Accuracy: 0.9836
# Finished Training
# Time taken for training: 1287.03 seconds
# Medium time per epoch: 32.18 seconds

# %%
# Load the model
model_path = '../models/' + f'{model_name}_font_classifier.pth'
model = models.__dict__[model_name](weights=None)
num_ftrs = model.fc.in_features
model.fc = torch.nn.Linear(num_ftrs, len(class_names))
model.load_state_dict(torch.load(model_path))
model = model.to(device)
print(f'Model loaded from {model_path}')
# Out:
# Model loaded from ../models/resnet18_font_classifier.pth

# %% [markdown]
# Evaluate the model

# %%
# Set the model to evaluation mode
model.eval()

# Initialize lists for true labels and predicted labels
true_labels = []
predicted_labels = []

# Disable gradient computation for evaluation
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        # Perform inference
        outputs = model(images)
        
        # Compute predicted labels
        _, predicted = torch.max(outputs.data, 1)
        
        # Append true and predicted labels to lists
        true_labels.extend(labels.cpu().numpy())
        predicted_labels.extend(predicted.cpu().numpy())

# Convert lists to numpy arrays
true_labels = np.array(true_labels)
predicted_labels = np.array(predicted_labels)

# Compute accuracy
accuracy = accuracy_score(true_labels, predicted_labels)
print('Accuracy: {:.2f}%'.format(100 * accuracy))

# Compute precision
precision = precision_score(true_labels, predicted_labels, average='weighted')
print('Precision: {:.2f}'.format(precision))

# Compute recall
recall = recall_score(true_labels, predicted_labels, average='weighted')
print('Recall: {:.2f}'.format(recall))

# Compute F1-score
f1 = f1_score(true_labels, predicted_labels, average='weighted')
print('F1-score: {:.2f}'.format(f1))

# Compute confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)
print(f'Confusion Matrix:')
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='g', cbar=False, xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Compute the ROC curve
# Binarize the true labels
true_labels_binarized = label_binarize(true_labels, classes=range(len(class_names)))

# Binarize the predicted labels
predicted_labels_binarized = label_binarize(predicted_labels, classes=range(len(class_names)))

# Compute the ROC curve
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(len(class_names)):
    fpr[i], tpr[i], _ = roc_curve(true_labels_binarized[:, i], predicted_labels_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
# Plot the ROC curve
plt.figure()
for i in range(len(class_names)):
    plt.plot(fpr[i], tpr[i], lw=2, label=f'ROC curve for class {class_names[i]} (area = {roc_auc[i]:0.2f})')
plt.plot([0, 1], [0, 1], 'k--', lw=2)
# Out:
# Accuracy: 99.07%
# Precision: 0.99
# Recall: 0.99
# F1-score: 0.99
# Confusion Matrix:
