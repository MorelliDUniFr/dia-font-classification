# %% [markdown]
# # Font Classification with PyTorch and ResNet18
# In this notebook, we will use the PyTorch deep learning framework to train a ResNet18 model to classify fonts. We will use the `torchvision` library to load the dataset and the `sklearn` library to evaluate the model using accuracy, precision, recall, F1-score, and the ROC curve. We will also visualize the confusion matrix to understand the model's performance on each class.

# %% [markdown]
# # Imports
# Import of the necessary libraries

# %%
import numpy as np
from torchvision import datasets, transforms
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import torch
from torchvision import models
from torch.utils.data import DataLoader
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import time
from sys import platform

# %% [markdown]
# # Model choice
# Choose the model to use for training. In this case, we will use the ResNet18 model.

# %%
model_name = 'resnet18'
print(f'Using model: {model_name}')
# Out:
# Using model: resnet18

# %% [markdown]
# # Loading and preparing the dataset
# Load the dataset and prepare it for training. We will resize the images to a fixed size, convert them to tensors, and normalize the pixel values.
#
# ## Preprocessing
# 1. Resize the images to a fixed size
# 2. Convert the images to tensors
# 3. Normalize the pixel values

# %%
# From the dataset, we know that the images have a height of 32 pixels and a width (on average) of 150 pixels
image_height = 32
image_width = 150

# Define the percentage of the dataset to use for training
train_size_perc = 0.7

# Set the seed for reproducibility
torch.manual_seed(0)

# Define transformations for preprocessing
transform = transforms.Compose([
    transforms.Resize((image_height, image_width)),  # Resize images to a fixed size
    transforms.ToTensor(),                           # Convert images to tensors
    transforms.Normalize(mean=[0.5, 0.5, 0.5],      # Normalize pixel values
                         std=[0.5, 0.5, 0.5])])

# %% [markdown]
# ## Load the dataset
# Load the dataset using the `ImageFolder` class from `torchvision`. We will split the dataset into training, validation, and test sets. We will use 70% of the dataset for training, 15% for validation, and 15% for testing.

# %%
# Path to the dataset
data_dir = '../fonts'

# Load the dataset using ImageFolder
dataset = datasets.ImageFolder(root=data_dir, transform=transform)

# Define the sizes of the training, validation, and test sets
train_size = int(train_size_perc * len(dataset))  # 70% of the dataset for training
val_size = int(((1.0 - train_size_perc)/2) * len(dataset))    # 15% for validation
test_size = len(dataset) - train_size - val_size  # Remaining for test (15%)

# Split the dataset into training, validation, and test sets
train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(
    dataset, [train_size, val_size, test_size])

# Define the batch size as a percentage of the training set, in this case 1%
batch_size = int(train_size * 0.01)

# Create data loaders for training, validation, and test sets
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## Dataset information

# %%
num_images = len(dataset)
num_batches = len(train_loader)
print(f'Number of images: {num_images}')
print(f'Number of batches: {num_batches}')
print(f'Batch size: {batch_size}')
print(f'Number of training images: {len(train_dataset)}')
print(f'Number of validation images: {len(val_dataset)}')
print(f'Number of test images: {len(test_dataset)}')

# Get the class names
class_names = dataset.classes
print(f'Class names: {class_names}')
# Out:
# Number of images: 15000
# Number of batches: 100
# Batch size: 105
# Number of training images: 10500
# Number of validation images: 2250
# Number of test images: 2250
# Class names: ['Algerian', 'Arial', 'Baskerville', 'Calibry', 'Calligraphy', 'Cambria', 'Comic Sans MS', 'Courier', 'Elephant', 'Fascinate', 'Georgia', 'Helvetica', 'Lucida Bright', 'Nasalization', 'Times New Roman']

# %% [markdown]
# # Loading the model
# Load the ResNet18 model and move it to the device (CPU or GPU).

# %%
# Load the model and replace the fully connected layer
model = models.__dict__[model_name](weights=None)

# Move model to the device (CPU or GPU)
if platform != "win32":
    device = torch.device('mps' if torch.backends.mps.is_available() else 'cpu')
else:
    device = torch.device('gpu' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
print(f'Model moved to {device}')
# Out:
# Model moved to mps

# %% [markdown]
# # Training the model
# Train the model using the training set and validate it using the validation set. We will use the Adam optimizer and the CrossEntropy loss function. We will save the model with the lowest validation loss.

# %%
# Define the loss function
criterion = torch.nn.CrossEntropyLoss()

# Define the optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 40
best_val_loss = float('inf')

# Lists to store training and validation metrics for plotting
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

# Set the model to training mode
model.train()

# Start the training loop
start_time = time.time()
for epoch in range(num_epochs):
    print(f'Epoch {epoch + 1}\n-------------------------------')
    # Training phase
    model.train()
    train_loss = 0.0
    correct_train = 0
    total_train = 0
    for i, (inputs, labels) in enumerate(train_loader):
        inputs = inputs.to(device)
        labels = labels.to(device)

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * inputs.size(0)
        
        # Calculate accuracy
        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

        # Print training statistics
        if (i + 1) % 10 == 0:
            print(f'Training - Epoch [{epoch + 1}/{num_epochs}], Step [{i + 1}/{len(train_loader)}], Loss: {loss.item():.4f}')

    # Calculate average training loss and accuracy
    train_loss /= len(train_loader.dataset)
    train_accuracy = correct_train / total_train
    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)
    
    # Validation phase
    model.eval()
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(val_loader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            val_loss += loss.item() * inputs.size(0)

            # Calculate accuracy
            _, predicted = torch.max(outputs, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    # Print validation statistics
    val_loss /= len(val_loader.dataset)
    val_accuracy = correct_val / total_val
    val_losses.append(val_loss)
    val_accuracies.append(val_accuracy)
    print(f'Validation - Epoch [{epoch + 1}/{num_epochs}], Loss: {val_loss:.4f}, Accuracy: {val_accuracy:.4f}')

    # Save the model if validation loss decreases
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), '../models/' + f'{model_name}_font_classifier.pth')
        print(f'Model saved as {model_name}_font_classifier.pth')

end_time = time.time()
# Out:
# Epoch 1
# -------------------------------
# Training - Epoch [1/40], Step [10/100], Loss: 1.3368
# Training - Epoch [1/40], Step [20/100], Loss: 0.7294
# Training - Epoch [1/40], Step [30/100], Loss: 0.4623
# Training - Epoch [1/40], Step [40/100], Loss: 0.4524
# Training - Epoch [1/40], Step [50/100], Loss: 0.5029
# Training - Epoch [1/40], Step [60/100], Loss: 0.4482
# Training - Epoch [1/40], Step [70/100], Loss: 0.3211
# Training - Epoch [1/40], Step [80/100], Loss: 0.2077
# Training - Epoch [1/40], Step [90/100], Loss: 0.2617
# Training - Epoch [1/40], Step [100/100], Loss: 0.1441
# Validation - Epoch [1/40], Loss: 0.2724, Accuracy: 0.9191
# Model saved as resnet18_font_classifier.pth
# Epoch 2
# -------------------------------
# Training - Epoch [2/40], Step [10/100], Loss: 0.2246
# Training - Epoch [2/40], Step [20/100], Loss: 0.1535
# Training - Epoch [2/40], Step [30/100], Loss: 0.0967
# Training - Epoch [2/40], Step [40/100], Loss: 0.2164
# Training - Epoch [2/40], Step [50/100], Loss: 0.0921
# Training - Epoch [2/40], Step [60/100], Loss: 0.0938
# Training - Epoch [2/40], Step [70/100], Loss: 0.1843
# Training - Epoch [2/40], Step [80/100], Loss: 0.1698
# Training - Epoch [2/40], Step [90/100], Loss: 0.1401
# Training - Epoch [2/40], Step [100/100], Loss: 0.1738
# Validation - Epoch [2/40], Loss: 0.3287, Accuracy: 0.9013
# Epoch 3
# -------------------------------
# Training - Epoch [3/40], Step [10/100], Loss: 0.1248
# Training - Epoch [3/40], Step [20/100], Loss: 0.2125
# Training - Epoch [3/40], Step [30/100], Loss: 0.2436
# Training - Epoch [3/40], Step [40/100], Loss: 0.0973
# Training - Epoch [3/40], Step [50/100], Loss: 0.1589
# Training - Epoch [3/40], Step [60/100], Loss: 0.0741
# Training - Epoch [3/40], Step [70/100], Loss: 0.0947
# Training - Epoch [3/40], Step [80/100], Loss: 0.0384
# Training - Epoch [3/40], Step [90/100], Loss: 0.1236
# Training - Epoch [3/40], Step [100/100], Loss: 0.0786
# Validation - Epoch [3/40], Loss: 0.1420, Accuracy: 0.9618
# Model saved as resnet18_font_classifier.pth
# Epoch 4
# -------------------------------
# Training - Epoch [4/40], Step [10/100], Loss: 0.0194
# Training - Epoch [4/40], Step [20/100], Loss: 0.0597
# Training - Epoch [4/40], Step [30/100], Loss: 0.0402
# Training - Epoch [4/40], Step [40/100], Loss: 0.0857
# Training - Epoch [4/40], Step [50/100], Loss: 0.0402
# Training - Epoch [4/40], Step [60/100], Loss: 0.0571
# Training - Epoch [4/40], Step [70/100], Loss: 0.0772
# Training - Epoch [4/40], Step [80/100], Loss: 0.0510
# Training - Epoch [4/40], Step [90/100], Loss: 0.0567
# Training - Epoch [4/40], Step [100/100], Loss: 0.0513
# Validation - Epoch [4/40], Loss: 0.1353, Accuracy: 0.9582
# Model saved as resnet18_font_classifier.pth
# Epoch 5
# -------------------------------
# Training - Epoch [5/40], Step [10/100], Loss: 0.0569
# Training - Epoch [5/40], Step [20/100], Loss: 0.1869
# Training - Epoch [5/40], Step [30/100], Loss: 0.0155
# Training - Epoch [5/40], Step [40/100], Loss: 0.0743
# Training - Epoch [5/40], Step [50/100], Loss: 0.0307
# Training - Epoch [5/40], Step [60/100], Loss: 0.0394
# Training - Epoch [5/40], Step [70/100], Loss: 0.0518
# Training - Epoch [5/40], Step [80/100], Loss: 0.0730
# Training - Epoch [5/40], Step [90/100], Loss: 0.0316
# Training - Epoch [5/40], Step [100/100], Loss: 0.0197
# Validation - Epoch [5/40], Loss: 0.1751, Accuracy: 0.9467
# Epoch 6
# -------------------------------
# Training - Epoch [6/40], Step [10/100], Loss: 0.0373
# Training - Epoch [6/40], Step [20/100], Loss: 0.0320
# Training - Epoch [6/40], Step [30/100], Loss: 0.0165
# Training - Epoch [6/40], Step [40/100], Loss: 0.0100
# Training - Epoch [6/40], Step [50/100], Loss: 0.0052
# Training - Epoch [6/40], Step [60/100], Loss: 0.0703
# Training - Epoch [6/40], Step [70/100], Loss: 0.0380
# Training - Epoch [6/40], Step [80/100], Loss: 0.0025
# Training - Epoch [6/40], Step [90/100], Loss: 0.0506
# Training - Epoch [6/40], Step [100/100], Loss: 0.0340
# Validation - Epoch [6/40], Loss: 0.1402, Accuracy: 0.9587
# Epoch 7
# -------------------------------
# Training - Epoch [7/40], Step [10/100], Loss: 0.0514
# Training - Epoch [7/40], Step [20/100], Loss: 0.0423
# Training - Epoch [7/40], Step [30/100], Loss: 0.0064
# Training - Epoch [7/40], Step [40/100], Loss: 0.0489
# Training - Epoch [7/40], Step [50/100], Loss: 0.0404
# Training - Epoch [7/40], Step [60/100], Loss: 0.0078
# Training - Epoch [7/40], Step [70/100], Loss: 0.0305
# Training - Epoch [7/40], Step [80/100], Loss: 0.0675
# Training - Epoch [7/40], Step [90/100], Loss: 0.1602
# Training - Epoch [7/40], Step [100/100], Loss: 0.0512
# Validation - Epoch [7/40], Loss: 0.0665, Accuracy: 0.9791
# Model saved as resnet18_font_classifier.pth
# Epoch 8
# -------------------------------
# Training - Epoch [8/40], Step [10/100], Loss: 0.0213
# Training - Epoch [8/40], Step [20/100], Loss: 0.0820
# Training - Epoch [8/40], Step [30/100], Loss: 0.0044
# Training - Epoch [8/40], Step [40/100], Loss: 0.0352
# Training - Epoch [8/40], Step [50/100], Loss: 0.0920
# Training - Epoch [8/40], Step [60/100], Loss: 0.1312
# Training - Epoch [8/40], Step [70/100], Loss: 0.0705
# Training - Epoch [8/40], Step [80/100], Loss: 0.0670
# Training - Epoch [8/40], Step [90/100], Loss: 0.0425
# Training - Epoch [8/40], Step [100/100], Loss: 0.0935
# Validation - Epoch [8/40], Loss: 0.5439, Accuracy: 0.8809
# Epoch 9
# -------------------------------
# Training - Epoch [9/40], Step [10/100], Loss: 0.0336
# Training - Epoch [9/40], Step [20/100], Loss: 0.0823
# Training - Epoch [9/40], Step [30/100], Loss: 0.0731
# Training - Epoch [9/40], Step [40/100], Loss: 0.0626
# Training - Epoch [9/40], Step [50/100], Loss: 0.0259
# Training - Epoch [9/40], Step [60/100], Loss: 0.1076
# Training - Epoch [9/40], Step [70/100], Loss: 0.0590
# Training - Epoch [9/40], Step [80/100], Loss: 0.0410
# Training - Epoch [9/40], Step [90/100], Loss: 0.0470
# Training - Epoch [9/40], Step [100/100], Loss: 0.0435
# Validation - Epoch [9/40], Loss: 0.0750, Accuracy: 0.9769
# Epoch 10
# -------------------------------
# Training - Epoch [10/40], Step [10/100], Loss: 0.0440
# Training - Epoch [10/40], Step [20/100], Loss: 0.0596
# Training - Epoch [10/40], Step [30/100], Loss: 0.0228
# Training - Epoch [10/40], Step [40/100], Loss: 0.0239
# Training - Epoch [10/40], Step [50/100], Loss: 0.0052
# Training - Epoch [10/40], Step [60/100], Loss: 0.0250
# Training - Epoch [10/40], Step [70/100], Loss: 0.1151
# Training - Epoch [10/40], Step [80/100], Loss: 0.0622
# Training - Epoch [10/40], Step [90/100], Loss: 0.0117
# Training - Epoch [10/40], Step [100/100], Loss: 0.0962
# Validation - Epoch [10/40], Loss: 0.0682, Accuracy: 0.9818
# Epoch 11
# -------------------------------
# Training - Epoch [11/40], Step [10/100], Loss: 0.0103
# Training - Epoch [11/40], Step [20/100], Loss: 0.0265
# Training - Epoch [11/40], Step [30/100], Loss: 0.0192
# Training - Epoch [11/40], Step [40/100], Loss: 0.0212
# Training - Epoch [11/40], Step [50/100], Loss: 0.0061
# Training - Epoch [11/40], Step [60/100], Loss: 0.0489
# Training - Epoch [11/40], Step [70/100], Loss: 0.0532
# Training - Epoch [11/40], Step [80/100], Loss: 0.0083
# Training - Epoch [11/40], Step [90/100], Loss: 0.0162
# Training - Epoch [11/40], Step [100/100], Loss: 0.0093
# Validation - Epoch [11/40], Loss: 0.2999, Accuracy: 0.9320
# Epoch 12
# -------------------------------
# Training - Epoch [12/40], Step [10/100], Loss: 0.0433
# Training - Epoch [12/40], Step [20/100], Loss: 0.0106
# Training - Epoch [12/40], Step [30/100], Loss: 0.0107
# Training - Epoch [12/40], Step [40/100], Loss: 0.0691
# Training - Epoch [12/40], Step [50/100], Loss: 0.0656
# Training - Epoch [12/40], Step [60/100], Loss: 0.0456
# Training - Epoch [12/40], Step [70/100], Loss: 0.0047
# Training - Epoch [12/40], Step [80/100], Loss: 0.0217
# Training - Epoch [12/40], Step [90/100], Loss: 0.0218
# Training - Epoch [12/40], Step [100/100], Loss: 0.0726
# Validation - Epoch [12/40], Loss: 0.1481, Accuracy: 0.9564
# Epoch 13
# -------------------------------
# Training - Epoch [13/40], Step [10/100], Loss: 0.0351
# Training - Epoch [13/40], Step [20/100], Loss: 0.0840
# Training - Epoch [13/40], Step [30/100], Loss: 0.0208
# Training - Epoch [13/40], Step [40/100], Loss: 0.0055
# Training - Epoch [13/40], Step [50/100], Loss: 0.0006
# Training - Epoch [13/40], Step [60/100], Loss: 0.0268
# Training - Epoch [13/40], Step [70/100], Loss: 0.0022
# Training - Epoch [13/40], Step [80/100], Loss: 0.0158
# Training - Epoch [13/40], Step [90/100], Loss: 0.0025
# Training - Epoch [13/40], Step [100/100], Loss: 0.0251
# Validation - Epoch [13/40], Loss: 0.0981, Accuracy: 0.9724
# Epoch 14
# -------------------------------
# Training - Epoch [14/40], Step [10/100], Loss: 0.0676
# Training - Epoch [14/40], Step [20/100], Loss: 0.0598
# Training - Epoch [14/40], Step [30/100], Loss: 0.0343
# Training - Epoch [14/40], Step [40/100], Loss: 0.0031
# Training - Epoch [14/40], Step [50/100], Loss: 0.0298
# Training - Epoch [14/40], Step [60/100], Loss: 0.0011
# Training - Epoch [14/40], Step [70/100], Loss: 0.0161
# Training - Epoch [14/40], Step [80/100], Loss: 0.0070
# Training - Epoch [14/40], Step [90/100], Loss: 0.0026
# Training - Epoch [14/40], Step [100/100], Loss: 0.0159
# Validation - Epoch [14/40], Loss: 0.0668, Accuracy: 0.9831
# Epoch 15
# -------------------------------
# Training - Epoch [15/40], Step [10/100], Loss: 0.0137
# Training - Epoch [15/40], Step [20/100], Loss: 0.0143
# Training - Epoch [15/40], Step [30/100], Loss: 0.0041
# Training - Epoch [15/40], Step [40/100], Loss: 0.0069
# Training - Epoch [15/40], Step [50/100], Loss: 0.0363
# Training - Epoch [15/40], Step [60/100], Loss: 0.0225
# Training - Epoch [15/40], Step [70/100], Loss: 0.0104
# Training - Epoch [15/40], Step [80/100], Loss: 0.0374
# Training - Epoch [15/40], Step [90/100], Loss: 0.0063
# Training - Epoch [15/40], Step [100/100], Loss: 0.0038
# Validation - Epoch [15/40], Loss: 0.0561, Accuracy: 0.9844
# Model saved as resnet18_font_classifier.pth
# Epoch 16
# -------------------------------
# Training - Epoch [16/40], Step [10/100], Loss: 0.0098
# Training - Epoch [16/40], Step [20/100], Loss: 0.0446
# Training - Epoch [16/40], Step [30/100], Loss: 0.0022
# Training - Epoch [16/40], Step [40/100], Loss: 0.0316
# Training - Epoch [16/40], Step [50/100], Loss: 0.0097
# Training - Epoch [16/40], Step [60/100], Loss: 0.0034
# Training - Epoch [16/40], Step [70/100], Loss: 0.0103
# Training - Epoch [16/40], Step [80/100], Loss: 0.0020
# Training - Epoch [16/40], Step [90/100], Loss: 0.0010
# Training - Epoch [16/40], Step [100/100], Loss: 0.0032
# Validation - Epoch [16/40], Loss: 0.0785, Accuracy: 0.9756
# Epoch 17
# -------------------------------
# Training - Epoch [17/40], Step [10/100], Loss: 0.0141
# Training - Epoch [17/40], Step [20/100], Loss: 0.0144
# Training - Epoch [17/40], Step [30/100], Loss: 0.0079
# Training - Epoch [17/40], Step [40/100], Loss: 0.0220
# Training - Epoch [17/40], Step [50/100], Loss: 0.0022
# Training - Epoch [17/40], Step [60/100], Loss: 0.0334
# Training - Epoch [17/40], Step [70/100], Loss: 0.0105
# Training - Epoch [17/40], Step [80/100], Loss: 0.0040
# Training - Epoch [17/40], Step [90/100], Loss: 0.0186
# Training - Epoch [17/40], Step [100/100], Loss: 0.0366
# Validation - Epoch [17/40], Loss: 0.0487, Accuracy: 0.9849
# Model saved as resnet18_font_classifier.pth
# Epoch 18
# -------------------------------
# Training - Epoch [18/40], Step [10/100], Loss: 0.0064
# Training - Epoch [18/40], Step [20/100], Loss: 0.0119
# Training - Epoch [18/40], Step [30/100], Loss: 0.0321
# Training - Epoch [18/40], Step [40/100], Loss: 0.0097
# Training - Epoch [18/40], Step [50/100], Loss: 0.0430
# Training - Epoch [18/40], Step [60/100], Loss: 0.0532
# Training - Epoch [18/40], Step [70/100], Loss: 0.0071
# Training - Epoch [18/40], Step [80/100], Loss: 0.0087
# Training - Epoch [18/40], Step [90/100], Loss: 0.0005
# Training - Epoch [18/40], Step [100/100], Loss: 0.0500
# Validation - Epoch [18/40], Loss: 0.0494, Accuracy: 0.9840
# Epoch 19
# -------------------------------
# Training - Epoch [19/40], Step [10/100], Loss: 0.0014
# Training - Epoch [19/40], Step [20/100], Loss: 0.0040
# Training - Epoch [19/40], Step [30/100], Loss: 0.0474
# Training - Epoch [19/40], Step [40/100], Loss: 0.0037
# Training - Epoch [19/40], Step [50/100], Loss: 0.0819
# Training - Epoch [19/40], Step [60/100], Loss: 0.0077
# Training - Epoch [19/40], Step [70/100], Loss: 0.0126
# Training - Epoch [19/40], Step [80/100], Loss: 0.0139
# Training - Epoch [19/40], Step [90/100], Loss: 0.0007
# Training - Epoch [19/40], Step [100/100], Loss: 0.0010
# Validation - Epoch [19/40], Loss: 0.0626, Accuracy: 0.9840
# Epoch 20
# -------------------------------
# Training - Epoch [20/40], Step [10/100], Loss: 0.0395
# Training - Epoch [20/40], Step [20/100], Loss: 0.0206
# Training - Epoch [20/40], Step [30/100], Loss: 0.0019
# Training - Epoch [20/40], Step [40/100], Loss: 0.0141
# Training - Epoch [20/40], Step [50/100], Loss: 0.0294
# Training - Epoch [20/40], Step [60/100], Loss: 0.0003
# Training - Epoch [20/40], Step [70/100], Loss: 0.0014
# Training - Epoch [20/40], Step [80/100], Loss: 0.0075
# Training - Epoch [20/40], Step [90/100], Loss: 0.0071
# Training - Epoch [20/40], Step [100/100], Loss: 0.0188
# Validation - Epoch [20/40], Loss: 0.0848, Accuracy: 0.9796
# Epoch 21
# -------------------------------
# Training - Epoch [21/40], Step [10/100], Loss: 0.0020
# Training - Epoch [21/40], Step [20/100], Loss: 0.0214
# Training - Epoch [21/40], Step [30/100], Loss: 0.0026
# Training - Epoch [21/40], Step [40/100], Loss: 0.0018
# Training - Epoch [21/40], Step [50/100], Loss: 0.0010
# Training - Epoch [21/40], Step [60/100], Loss: 0.0051
# Training - Epoch [21/40], Step [70/100], Loss: 0.0062
# Training - Epoch [21/40], Step [80/100], Loss: 0.0071
# Training - Epoch [21/40], Step [90/100], Loss: 0.0005
# Training - Epoch [21/40], Step [100/100], Loss: 0.0514
# Validation - Epoch [21/40], Loss: 0.1189, Accuracy: 0.9720
# Epoch 22
# -------------------------------
# Training - Epoch [22/40], Step [10/100], Loss: 0.0028
# Training - Epoch [22/40], Step [20/100], Loss: 0.0356
# Training - Epoch [22/40], Step [30/100], Loss: 0.0017
# Training - Epoch [22/40], Step [40/100], Loss: 0.0097
# Training - Epoch [22/40], Step [50/100], Loss: 0.0459
# Training - Epoch [22/40], Step [60/100], Loss: 0.0556
# Training - Epoch [22/40], Step [70/100], Loss: 0.0221
# Training - Epoch [22/40], Step [80/100], Loss: 0.0920
# Training - Epoch [22/40], Step [90/100], Loss: 0.0012
# Training - Epoch [22/40], Step [100/100], Loss: 0.0243
# Validation - Epoch [22/40], Loss: 0.2647, Accuracy: 0.9293
# Epoch 23
# -------------------------------
# Training - Epoch [23/40], Step [10/100], Loss: 0.0429
# Training - Epoch [23/40], Step [20/100], Loss: 0.0754
# Training - Epoch [23/40], Step [30/100], Loss: 0.0822
# Training - Epoch [23/40], Step [40/100], Loss: 0.0164
# Training - Epoch [23/40], Step [50/100], Loss: 0.0084
# Training - Epoch [23/40], Step [60/100], Loss: 0.0567
# Training - Epoch [23/40], Step [70/100], Loss: 0.0030
# Training - Epoch [23/40], Step [80/100], Loss: 0.0108
# Training - Epoch [23/40], Step [90/100], Loss: 0.0331
# Training - Epoch [23/40], Step [100/100], Loss: 0.0105
# Validation - Epoch [23/40], Loss: 0.1126, Accuracy: 0.9702
# Epoch 24
# -------------------------------
# Training - Epoch [24/40], Step [10/100], Loss: 0.0488
# Training - Epoch [24/40], Step [20/100], Loss: 0.0020
# Training - Epoch [24/40], Step [30/100], Loss: 0.0026
# Training - Epoch [24/40], Step [40/100], Loss: 0.1060
# Training - Epoch [24/40], Step [50/100], Loss: 0.0556
# Training - Epoch [24/40], Step [60/100], Loss: 0.0445
# Training - Epoch [24/40], Step [70/100], Loss: 0.0628
# Training - Epoch [24/40], Step [80/100], Loss: 0.0128
# Training - Epoch [24/40], Step [90/100], Loss: 0.0118
# Training - Epoch [24/40], Step [100/100], Loss: 0.0225
# Validation - Epoch [24/40], Loss: 0.0718, Accuracy: 0.9818
# Epoch 25
# -------------------------------
# Training - Epoch [25/40], Step [10/100], Loss: 0.0097
# Training - Epoch [25/40], Step [20/100], Loss: 0.0040
# Training - Epoch [25/40], Step [30/100], Loss: 0.0123
# Training - Epoch [25/40], Step [40/100], Loss: 0.0440
# Training - Epoch [25/40], Step [50/100], Loss: 0.0086
# Training - Epoch [25/40], Step [60/100], Loss: 0.0015
# Training - Epoch [25/40], Step [70/100], Loss: 0.0027
# Training - Epoch [25/40], Step [80/100], Loss: 0.0009
# Training - Epoch [25/40], Step [90/100], Loss: 0.0170
# Training - Epoch [25/40], Step [100/100], Loss: 0.0330
# Validation - Epoch [25/40], Loss: 0.0454, Accuracy: 0.9867
# Model saved as resnet18_font_classifier.pth
# Epoch 26
# -------------------------------
# Training - Epoch [26/40], Step [10/100], Loss: 0.0061
# Training - Epoch [26/40], Step [20/100], Loss: 0.0006
# Training - Epoch [26/40], Step [30/100], Loss: 0.0007
# Training - Epoch [26/40], Step [40/100], Loss: 0.0008
# Training - Epoch [26/40], Step [50/100], Loss: 0.0051
# Training - Epoch [26/40], Step [60/100], Loss: 0.0006
# Training - Epoch [26/40], Step [70/100], Loss: 0.0020
# Training - Epoch [26/40], Step [80/100], Loss: 0.0031
# Training - Epoch [26/40], Step [90/100], Loss: 0.0007
# Training - Epoch [26/40], Step [100/100], Loss: 0.0017
# Validation - Epoch [26/40], Loss: 0.0412, Accuracy: 0.9884
# Model saved as resnet18_font_classifier.pth
# Epoch 27
# -------------------------------
# Training - Epoch [27/40], Step [10/100], Loss: 0.0005
# Training - Epoch [27/40], Step [20/100], Loss: 0.0004
# Training - Epoch [27/40], Step [30/100], Loss: 0.0002
# Training - Epoch [27/40], Step [40/100], Loss: 0.0044
# Training - Epoch [27/40], Step [50/100], Loss: 0.0013
# Training - Epoch [27/40], Step [60/100], Loss: 0.0210
# Training - Epoch [27/40], Step [70/100], Loss: 0.0006
# Training - Epoch [27/40], Step [80/100], Loss: 0.0005
# Training - Epoch [27/40], Step [90/100], Loss: 0.0009
# Training - Epoch [27/40], Step [100/100], Loss: 0.0063
# Validation - Epoch [27/40], Loss: 0.0462, Accuracy: 0.9893
# Epoch 28
# -------------------------------
# Training - Epoch [28/40], Step [10/100], Loss: 0.0021
# Training - Epoch [28/40], Step [20/100], Loss: 0.0003
# Training - Epoch [28/40], Step [30/100], Loss: 0.0020
# Training - Epoch [28/40], Step [40/100], Loss: 0.0117
# Training - Epoch [28/40], Step [50/100], Loss: 0.0003
# Training - Epoch [28/40], Step [60/100], Loss: 0.0034
# Training - Epoch [28/40], Step [70/100], Loss: 0.0087
# Training - Epoch [28/40], Step [80/100], Loss: 0.0110
# Training - Epoch [28/40], Step [90/100], Loss: 0.0823
# Training - Epoch [28/40], Step [100/100], Loss: 0.0051
# Validation - Epoch [28/40], Loss: 0.0634, Accuracy: 0.9818
# Epoch 29
# -------------------------------
# Training - Epoch [29/40], Step [10/100], Loss: 0.0115
# Training - Epoch [29/40], Step [20/100], Loss: 0.0031
# Training - Epoch [29/40], Step [30/100], Loss: 0.0109
# Training - Epoch [29/40], Step [40/100], Loss: 0.0136
# Training - Epoch [29/40], Step [50/100], Loss: 0.0345
# Training - Epoch [29/40], Step [60/100], Loss: 0.0329
# Training - Epoch [29/40], Step [70/100], Loss: 0.0377
# Training - Epoch [29/40], Step [80/100], Loss: 0.0314
# Training - Epoch [29/40], Step [90/100], Loss: 0.0148
# Training - Epoch [29/40], Step [100/100], Loss: 0.0047
# Validation - Epoch [29/40], Loss: 0.1686, Accuracy: 0.9596
# Epoch 30
# -------------------------------
# Training - Epoch [30/40], Step [10/100], Loss: 0.1460
# Training - Epoch [30/40], Step [20/100], Loss: 0.1301
# Training - Epoch [30/40], Step [30/100], Loss: 0.0512
# Training - Epoch [30/40], Step [40/100], Loss: 0.0070
# Training - Epoch [30/40], Step [50/100], Loss: 0.0523
# Training - Epoch [30/40], Step [60/100], Loss: 0.0063
# Training - Epoch [30/40], Step [70/100], Loss: 0.0115
# Training - Epoch [30/40], Step [80/100], Loss: 0.0164
# Training - Epoch [30/40], Step [90/100], Loss: 0.0088
# Training - Epoch [30/40], Step [100/100], Loss: 0.0045
# Validation - Epoch [30/40], Loss: 0.1375, Accuracy: 0.9622
# Epoch 31
# -------------------------------
# Training - Epoch [31/40], Step [10/100], Loss: 0.0056
# Training - Epoch [31/40], Step [20/100], Loss: 0.0006
# Training - Epoch [31/40], Step [30/100], Loss: 0.1096
# Training - Epoch [31/40], Step [40/100], Loss: 0.0836
# Training - Epoch [31/40], Step [50/100], Loss: 0.0452
# Training - Epoch [31/40], Step [60/100], Loss: 0.0096
# Training - Epoch [31/40], Step [70/100], Loss: 0.0065
# Training - Epoch [31/40], Step [80/100], Loss: 0.0205
# Training - Epoch [31/40], Step [90/100], Loss: 0.0480
# Training - Epoch [31/40], Step [100/100], Loss: 0.0416
# Validation - Epoch [31/40], Loss: 0.0443, Accuracy: 0.9867
# Epoch 32
# -------------------------------
# Training - Epoch [32/40], Step [10/100], Loss: 0.0004
# Training - Epoch [32/40], Step [20/100], Loss: 0.0015
# Training - Epoch [32/40], Step [30/100], Loss: 0.0020
# Training - Epoch [32/40], Step [40/100], Loss: 0.0013
# Training - Epoch [32/40], Step [50/100], Loss: 0.0045
# Training - Epoch [32/40], Step [60/100], Loss: 0.0028
# Training - Epoch [32/40], Step [70/100], Loss: 0.0279
# Training - Epoch [32/40], Step [80/100], Loss: 0.0015
# Training - Epoch [32/40], Step [90/100], Loss: 0.0220
# Training - Epoch [32/40], Step [100/100], Loss: 0.0042
# Validation - Epoch [32/40], Loss: 0.2801, Accuracy: 0.9476
# Epoch 33
# -------------------------------
# Training - Epoch [33/40], Step [10/100], Loss: 0.0062
# Training - Epoch [33/40], Step [20/100], Loss: 0.0499
# Training - Epoch [33/40], Step [30/100], Loss: 0.0014
# Training - Epoch [33/40], Step [40/100], Loss: 0.0475
# Training - Epoch [33/40], Step [50/100], Loss: 0.0007
# Training - Epoch [33/40], Step [60/100], Loss: 0.0017
# Training - Epoch [33/40], Step [70/100], Loss: 0.0016
# Training - Epoch [33/40], Step [80/100], Loss: 0.0157
# Training - Epoch [33/40], Step [90/100], Loss: 0.0013
# Training - Epoch [33/40], Step [100/100], Loss: 0.0024
# Validation - Epoch [33/40], Loss: 0.0491, Accuracy: 0.9867
# Epoch 34
# -------------------------------
# Training - Epoch [34/40], Step [10/100], Loss: 0.0021
# Training - Epoch [34/40], Step [20/100], Loss: 0.0016
# Training - Epoch [34/40], Step [30/100], Loss: 0.0006
# Training - Epoch [34/40], Step [40/100], Loss: 0.0950
# Training - Epoch [34/40], Step [50/100], Loss: 0.0182
# Training - Epoch [34/40], Step [60/100], Loss: 0.0043
# Training - Epoch [34/40], Step [70/100], Loss: 0.0078
# Training - Epoch [34/40], Step [80/100], Loss: 0.0022
# Training - Epoch [34/40], Step [90/100], Loss: 0.0022
# Training - Epoch [34/40], Step [100/100], Loss: 0.0101
# Validation - Epoch [34/40], Loss: 0.2617, Accuracy: 0.9444
# Epoch 35
# -------------------------------
# Training - Epoch [35/40], Step [10/100], Loss: 0.0015
# Training - Epoch [35/40], Step [20/100], Loss: 0.0702
# Training - Epoch [35/40], Step [30/100], Loss: 0.0038
# Training - Epoch [35/40], Step [40/100], Loss: 0.0769
# Training - Epoch [35/40], Step [50/100], Loss: 0.0333
# Training - Epoch [35/40], Step [60/100], Loss: 0.0007
# Training - Epoch [35/40], Step [70/100], Loss: 0.0011
# Training - Epoch [35/40], Step [80/100], Loss: 0.0045
# Training - Epoch [35/40], Step [90/100], Loss: 0.0044
# Training - Epoch [35/40], Step [100/100], Loss: 0.0542
# Validation - Epoch [35/40], Loss: 0.0386, Accuracy: 0.9880
# Model saved as resnet18_font_classifier.pth
# Epoch 36
# -------------------------------
# Training - Epoch [36/40], Step [10/100], Loss: 0.0002
# Training - Epoch [36/40], Step [20/100], Loss: 0.0007
# Training - Epoch [36/40], Step [30/100], Loss: 0.0004
# Training - Epoch [36/40], Step [40/100], Loss: 0.0010
# Training - Epoch [36/40], Step [50/100], Loss: 0.0007
# Training - Epoch [36/40], Step [60/100], Loss: 0.0105
# Training - Epoch [36/40], Step [70/100], Loss: 0.0033
# Training - Epoch [36/40], Step [80/100], Loss: 0.0010
# Training - Epoch [36/40], Step [90/100], Loss: 0.0002
# Training - Epoch [36/40], Step [100/100], Loss: 0.0003
# Validation - Epoch [36/40], Loss: 0.0323, Accuracy: 0.9916
# Model saved as resnet18_font_classifier.pth
# Epoch 37
# -------------------------------
# Training - Epoch [37/40], Step [10/100], Loss: 0.0026
# Training - Epoch [37/40], Step [20/100], Loss: 0.0009
# Training - Epoch [37/40], Step [30/100], Loss: 0.0321
# Training - Epoch [37/40], Step [40/100], Loss: 0.0004
# Training - Epoch [37/40], Step [50/100], Loss: 0.0001
# Training - Epoch [37/40], Step [60/100], Loss: 0.0003
# Training - Epoch [37/40], Step [70/100], Loss: 0.0004
# Training - Epoch [37/40], Step [80/100], Loss: 0.0001
# Training - Epoch [37/40], Step [90/100], Loss: 0.0003
# Training - Epoch [37/40], Step [100/100], Loss: 0.0002
# Validation - Epoch [37/40], Loss: 0.0385, Accuracy: 0.9907
# Epoch 38
# -------------------------------
# Training - Epoch [38/40], Step [10/100], Loss: 0.0005
# Training - Epoch [38/40], Step [20/100], Loss: 0.0001
# Training - Epoch [38/40], Step [30/100], Loss: 0.0014
# Training - Epoch [38/40], Step [40/100], Loss: 0.0004
# Training - Epoch [38/40], Step [50/100], Loss: 0.0003
# Training - Epoch [38/40], Step [60/100], Loss: 0.0001
# Training - Epoch [38/40], Step [70/100], Loss: 0.0003
# Training - Epoch [38/40], Step [80/100], Loss: 0.0003
# Training - Epoch [38/40], Step [90/100], Loss: 0.0003
# Training - Epoch [38/40], Step [100/100], Loss: 0.0076
# Validation - Epoch [38/40], Loss: 0.0313, Accuracy: 0.9902
# Model saved as resnet18_font_classifier.pth
# Epoch 39
# -------------------------------
# Training - Epoch [39/40], Step [10/100], Loss: 0.0001
# Training - Epoch [39/40], Step [20/100], Loss: 0.0020
# Training - Epoch [39/40], Step [30/100], Loss: 0.0001
# Training - Epoch [39/40], Step [40/100], Loss: 0.0091
# Training - Epoch [39/40], Step [50/100], Loss: 0.0004
# Training - Epoch [39/40], Step [60/100], Loss: 0.0002
# Training - Epoch [39/40], Step [70/100], Loss: 0.0003
# Training - Epoch [39/40], Step [80/100], Loss: 0.0003
# Training - Epoch [39/40], Step [90/100], Loss: 0.0053
# Training - Epoch [39/40], Step [100/100], Loss: 0.0001
# Validation - Epoch [39/40], Loss: 0.0304, Accuracy: 0.9929
# Model saved as resnet18_font_classifier.pth
# Epoch 40
# -------------------------------
# Training - Epoch [40/40], Step [10/100], Loss: 0.0002
# Training - Epoch [40/40], Step [20/100], Loss: 0.0007
# Training - Epoch [40/40], Step [30/100], Loss: 0.0003
# Training - Epoch [40/40], Step [40/100], Loss: 0.0003
# Training - Epoch [40/40], Step [50/100], Loss: 0.0001
# Training - Epoch [40/40], Step [60/100], Loss: 0.0058
# Training - Epoch [40/40], Step [70/100], Loss: 0.0002
# Training - Epoch [40/40], Step [80/100], Loss: 0.0001
# Training - Epoch [40/40], Step [90/100], Loss: 0.0000
# Training - Epoch [40/40], Step [100/100], Loss: 0.0007
# Validation - Epoch [40/40], Loss: 0.0320, Accuracy: 0.9924

# %% [markdown]
# # Plot the training and validation metrics

# %%
# Plotting
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), train_losses, label='Training Loss')
plt.plot(range(1, num_epochs + 1), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), train_accuracies, label='Training Accuracy')
plt.plot(range(1, num_epochs + 1), val_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

print('Finished Training')

# Print the time taken for training
print(f'Time taken for training: {end_time - start_time:.2f} seconds')
## Print medium time per epoch
print(f'Medium time per epoch: {(end_time - start_time)/num_epochs:.2f} seconds')
# Out:
# Finished Training
# Time taken for training: 1266.63 seconds
# Medium time per epoch: 31.67 seconds

# %% [markdown]
# # Evaluate the model

# %% [markdown]
# ## Load the model

# %%
# Load the model
model_path = '../models/' + f'{model_name}_font_classifier.pth'
model = models.__dict__[model_name](weights=None)
model.load_state_dict(torch.load(model_path))
model = model.to(device)
print(f'Model loaded from {model_path}')
# Out:
# Model loaded from ../models/resnet18_font_classifier.pth

# %% [markdown]
# ## Evaluate the model
# Evaluate the model using the test set. We will compute the accuracy, precision, recall, F1-score, confusion matrix, and ROC curve.

# %%
# Set the model to evaluation mode
model.eval()

# Initialize lists for true labels and predicted labels
true_labels = []
predicted_labels = []

# Disable gradient computation for evaluation
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        # Perform inference
        outputs = model(images)
        
        # Compute predicted labels
        _, predicted = torch.max(outputs.data, 1)
        
        # Append true and predicted labels to lists
        true_labels.extend(labels.cpu().numpy())
        predicted_labels.extend(predicted.cpu().numpy())

# Convert lists to numpy arrays
true_labels = np.array(true_labels)
predicted_labels = np.array(predicted_labels)

# %% [markdown]
# ## Compute metrics
# ### Accuracy

# %%
accuracy = accuracy_score(true_labels, predicted_labels)
print('Accuracy: {:.2f}%'.format(100 * accuracy))
# Out:
# Accuracy: 99.16%

# %% [markdown]
# ### Precision

# %%
precision = precision_score(true_labels, predicted_labels, average='weighted')
print('Precision: {:.2f}'.format(precision))
# Out:
# Precision: 0.99

# %% [markdown]
# ### Recall

# %%
recall = recall_score(true_labels, predicted_labels, average='weighted')
print('Recall: {:.2f}'.format(recall))
# Out:
# Recall: 0.99

# %% [markdown]
# ### F1-score

# %%
f1 = f1_score(true_labels, predicted_labels, average='weighted')
print('F1-score: {:.2f}'.format(f1))
# Out:
# F1-score: 0.99

# %% [markdown]
# ### Confusion matrix

# %%
conf_matrix = confusion_matrix(true_labels, predicted_labels)
print(f'Confusion Matrix:')
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='g', cbar=False, xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Confusion Matrix:

# %% [markdown]
# ### ROC curve

# %%
# Binarize the true labels
true_labels_binarized = label_binarize(true_labels, classes=range(len(class_names)))

# Binarize the predicted labels
predicted_labels_binarized = label_binarize(predicted_labels, classes=range(len(class_names)))

# Compute the ROC curve
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(len(class_names)):
    fpr[i], tpr[i], _ = roc_curve(true_labels_binarized[:, i], predicted_labels_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
# Plot the ROC curve
plt.figure()
for i in range(len(class_names)):
    plt.plot(fpr[i], tpr[i], lw=2, label=f'ROC curve for class {class_names[i]} (area = {roc_auc[i]:0.2f})')
plt.plot([0, 1], [0, 1], 'k--', lw=2)
