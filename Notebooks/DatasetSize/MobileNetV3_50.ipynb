# %% [markdown]
# # Font Classification with PyTorch and MobileNetV3
# In this notebook, we will use the PyTorch deep learning framework to train a MobileNetV3 model to classify fonts. We will use the `torchvision` library to load the dataset and the `sklearn` library to evaluate the model using accuracy, precision, recall, F1-score, and the ROC curve. We will also visualize the confusion matrix to understand the model's performance on each class.

# %% [markdown]
# # Imports
# Import of the necessary libraries

# %%
import numpy as np
from torchvision import datasets, transforms
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import torch
from torchvision import models
from torch.utils.data import DataLoader
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import time
from sys import platform

# %% [markdown]
# # Model choice
# Choose the model to use for training. In this case, we will use the MobileNetV3 model.

# %%
model_name = 'mobilenet_v3_small'
print(f'Using model: {model_name}')
# Out:
# Using model: mobilenet_v3_small

# %% [markdown]
# # Loading and preparing the dataset
# Load the dataset and prepare it for training. We will resize the images to a fixed size, convert them to tensors, and normalize the pixel values.
#
# ## Preprocessing
# 1. Resize the images to a fixed size
# 2. Convert the images to tensors
# 3. Normalize the pixel values

# %%
# From the dataset, we know that the images have a height of 32 pixels and a width (on average) of 150 pixels
image_height = 32
image_width = 150

# Define the percentage of the dataset to use for training
train_size_perc = 0.7

# Set the seed for reproducibility
torch.manual_seed(0)

# Define transformations for preprocessing
transform = transforms.Compose([
    transforms.Resize((image_height, image_width)),  # Resize images to a fixed size
    transforms.ToTensor(),                           # Convert images to tensors
    transforms.Normalize(mean=[0.25, 0.25, 0.25],      # Normalize pixel values
                         std=[0.25, 0.25, 0.25])])

# %% [markdown]
# ## Load the dataset
# Load the dataset using the `ImageFolder` class from `torchvision`. We will split the dataset into training, validation, and test sets. We will use 70% of the dataset for training, 15% for validation, and 15% for testing.

# %%
from collections import defaultdict
from torchvision.datasets import ImageFolder

# Path to the dataset
data_dir = '../../fonts'

# Notebook scope and type
scope = 'DatasetSize'
type = '50'

# Load the dataset using ImageFolder
dataset = datasets.ImageFolder(root=data_dir, transform=transform)

# Load only 5% of the dataset
# Collect indices of samples for each class
indices_by_class = defaultdict(list)
for i, (_, label) in enumerate(dataset.samples):
    indices_by_class[label].append(i)

# Choose 50 samples for each class
selected_indices = []
for indices in indices_by_class.values():
    selected_indices.extend(np.random.choice(indices, min(50, len(indices)), replace=False))

# Overwrite dataset.samples with the selected samples
dataset.samples = [dataset.samples[i] for i in selected_indices]

print(f'Loaded {len(dataset)} images')

# Display the class names
print(f'Class names: {dataset.classes}')

# Define the sizes of the training, validation, and test sets
train_size = int(train_size_perc * len(dataset))  # 70% of the dataset for training
val_size = int(((1.0 - train_size_perc)/2) * len(dataset))    # 15% for validation
test_size = len(dataset) - train_size - val_size  # Remaining for test

# Split the dataset into training, validation, and test sets
train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(
    dataset, [train_size, val_size, test_size])

# Define the batch size as a percentage of the training set, in this case 1%
batch_size = int(train_size * 0.01)

# Create data loaders for training, validation, and test sets
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Loaded 750 images
# Class names: ['Algerian', 'Arial', 'Baskerville', 'Calibry', 'Calligraphy', 'Cambria', 'Comic Sans MS', 'Courier', 'Elephant', 'Fascinate', 'Georgia', 'Helvetica', 'Lucida Bright', 'Nasalization', 'Times New Roman']

# %% [markdown]
# ## Dataset information

# %%
num_images = len(dataset)
num_batches = len(train_loader)
print(f'Number of images: {num_images}')
print(f'Number of batches: {num_batches}')
print(f'Batch size: {batch_size}')
print(f'Number of training images: {len(train_dataset)}')
print(f'Number of validation images: {len(val_dataset)}')
print(f'Number of test images: {len(test_dataset)}')

# Get the class names
class_names = dataset.classes
print(f'Class names: {class_names}')
# Out:
# Number of images: 750
# Number of batches: 105
# Batch size: 5
# Number of training images: 525
# Number of validation images: 112
# Number of test images: 113
# Class names: ['Algerian', 'Arial', 'Baskerville', 'Calibry', 'Calligraphy', 'Cambria', 'Comic Sans MS', 'Courier', 'Elephant', 'Fascinate', 'Georgia', 'Helvetica', 'Lucida Bright', 'Nasalization', 'Times New Roman']

# %% [markdown]
# # Loading the model
# Load the MobileNetV3 model and move it to the device (CPU or GPU).

# %%
# Load the model and replace the fully connected layer
model = models.__dict__[model_name](weights=None)

# Move model to the device (CPU or GPU)
if platform != "win32":
    device = torch.device('mps' if torch.backends.mps.is_available() else 'cpu')
else:
    device = torch.device('gpu' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
print(f'Model moved to {device}')
# Out:
# Model moved to cpu

# %% [markdown]
# # Training the model
# Train the model using the training set and validate it using the validation set. We will use the Adam optimizer and the CrossEntropy loss function. We will save the model with the lowest validation loss.

# %%
# Define the loss function
criterion = torch.nn.CrossEntropyLoss()

# Define the optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 60
best_val_loss = float('inf')

# Lists to store training and validation metrics for plotting
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

# Set the model to training mode
model.train()

# Start the training loop
start_time = time.time()
for epoch in range(num_epochs):
    print(f'Epoch {epoch + 1}\n-------------------------------')
    # Training phase
    model.train()
    train_loss = 0.0
    correct_train = 0
    total_train = 0
    for i, (inputs, labels) in enumerate(train_loader):
        inputs = inputs.to(device)
        labels = labels.to(device)

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * inputs.size(0)
        
        # Calculate accuracy
        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

        # Print training statistics
        if (i + 1) % 10 == 0:
            print(f'Training - Epoch [{epoch + 1}/{num_epochs}], Step [{i + 1}/{len(train_loader)}], Loss: {loss.item():.4f}')

    # Calculate average training loss and accuracy
    train_loss /= len(train_loader.dataset)
    train_accuracy = correct_train / total_train
    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)
    
    # Validation phase
    model.eval()
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(val_loader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            val_loss += loss.item() * inputs.size(0)

            # Calculate accuracy
            _, predicted = torch.max(outputs, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    # Print validation statistics
    val_loss /= len(val_loader.dataset)
    val_accuracy = correct_val / total_val
    val_losses.append(val_loss)
    val_accuracies.append(val_accuracy)
    print(f'Validation - Epoch [{epoch + 1}/{num_epochs}], Loss: {val_loss:.4f}, Accuracy: {val_accuracy:.4f}')

    # Save the model if validation loss decreases
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), f'../../models/{scope}/{model_name}_font_classifier_{type}.pth')
        print(f'Model saved as {model_name}_font_classifier_{type}.pth')

end_time = time.time()
# Out:
# Epoch 1
# -------------------------------
# Training - Epoch [1/60], Step [10/105], Loss: 5.8681
# Training - Epoch [1/60], Step [20/105], Loss: 2.1846
# Training - Epoch [1/60], Step [30/105], Loss: 3.3581
# Training - Epoch [1/60], Step [40/105], Loss: 2.6489
# Training - Epoch [1/60], Step [50/105], Loss: 2.5498
# Training - Epoch [1/60], Step [60/105], Loss: 2.9843
# Training - Epoch [1/60], Step [70/105], Loss: 2.2622
# Training - Epoch [1/60], Step [80/105], Loss: 3.0658
# Training - Epoch [1/60], Step [90/105], Loss: 2.5767
# Training - Epoch [1/60], Step [100/105], Loss: 2.7119
# Validation - Epoch [1/60], Loss: 4.8830, Accuracy: 0.0714
# Model saved as mobilenet_v3_small_font_classifier_50.pth
# Epoch 2
# -------------------------------
# Training - Epoch [2/60], Step [10/105], Loss: 2.3175
# Training - Epoch [2/60], Step [20/105], Loss: 2.7331
# Training - Epoch [2/60], Step [30/105], Loss: 2.3170
# Training - Epoch [2/60], Step [40/105], Loss: 2.3586
# Training - Epoch [2/60], Step [50/105], Loss: 2.0919
# Training - Epoch [2/60], Step [60/105], Loss: 1.8684
# Training - Epoch [2/60], Step [70/105], Loss: 2.8166
# Training - Epoch [2/60], Step [80/105], Loss: 3.3693
# Training - Epoch [2/60], Step [90/105], Loss: 2.1404
# Training - Epoch [2/60], Step [100/105], Loss: 2.0626
# Validation - Epoch [2/60], Loss: 3.6915, Accuracy: 0.0982
# Model saved as mobilenet_v3_small_font_classifier_50.pth
# Epoch 3
# -------------------------------
# Training - Epoch [3/60], Step [10/105], Loss: 2.0061
# Training - Epoch [3/60], Step [20/105], Loss: 2.8041
# Training - Epoch [3/60], Step [30/105], Loss: 2.6398
# Training - Epoch [3/60], Step [40/105], Loss: 2.2562
# Training - Epoch [3/60], Step [50/105], Loss: 2.1299
# Training - Epoch [3/60], Step [60/105], Loss: 2.1847
# Training - Epoch [3/60], Step [70/105], Loss: 1.4738
# Training - Epoch [3/60], Step [80/105], Loss: 1.9798
# Training - Epoch [3/60], Step [90/105], Loss: 2.9151
# Training - Epoch [3/60], Step [100/105], Loss: 2.5773
# Validation - Epoch [3/60], Loss: 3.0675, Accuracy: 0.0446
# Model saved as mobilenet_v3_small_font_classifier_50.pth
# Epoch 4
# -------------------------------
# Training - Epoch [4/60], Step [10/105], Loss: 2.5044
# Training - Epoch [4/60], Step [20/105], Loss: 2.1480
# Training - Epoch [4/60], Step [30/105], Loss: 1.5972
# Training - Epoch [4/60], Step [40/105], Loss: 2.2458
# Training - Epoch [4/60], Step [50/105], Loss: 2.8563
# Training - Epoch [4/60], Step [60/105], Loss: 2.5640
# Training - Epoch [4/60], Step [70/105], Loss: 1.4135
# Training - Epoch [4/60], Step [80/105], Loss: 1.9946
# Training - Epoch [4/60], Step [90/105], Loss: 2.8452
# Training - Epoch [4/60], Step [100/105], Loss: 2.3531
# Validation - Epoch [4/60], Loss: 2.9973, Accuracy: 0.0982
# Model saved as mobilenet_v3_small_font_classifier_50.pth
# Epoch 5
# -------------------------------
# Training - Epoch [5/60], Step [10/105], Loss: 2.1581
# Training - Epoch [5/60], Step [20/105], Loss: 1.8960
# Training - Epoch [5/60], Step [30/105], Loss: 2.5906
# Training - Epoch [5/60], Step [40/105], Loss: 1.9318
# Training - Epoch [5/60], Step [50/105], Loss: 2.6273
# Training - Epoch [5/60], Step [60/105], Loss: 1.8684
# Training - Epoch [5/60], Step [70/105], Loss: 1.6276
# Training - Epoch [5/60], Step [80/105], Loss: 2.2644
# Training - Epoch [5/60], Step [90/105], Loss: 2.7344
# Training - Epoch [5/60], Step [100/105], Loss: 1.8640
# Validation - Epoch [5/60], Loss: 2.8159, Accuracy: 0.0804
# Model saved as mobilenet_v3_small_font_classifier_50.pth
# Epoch 6
# -------------------------------
# Training - Epoch [6/60], Step [10/105], Loss: 1.5148
# Training - Epoch [6/60], Step [20/105], Loss: 0.9943
# Training - Epoch [6/60], Step [30/105], Loss: 2.3589
# Training - Epoch [6/60], Step [40/105], Loss: 1.0414
# Training - Epoch [6/60], Step [50/105], Loss: 1.4803
# Training - Epoch [6/60], Step [60/105], Loss: 1.8455
# Training - Epoch [6/60], Step [70/105], Loss: 1.6047
# Training - Epoch [6/60], Step [80/105], Loss: 1.9214
# Training - Epoch [6/60], Step [90/105], Loss: 2.1305
# Training - Epoch [6/60], Step [100/105], Loss: 1.9266
# Validation - Epoch [6/60], Loss: 2.2905, Accuracy: 0.2143
# Model saved as mobilenet_v3_small_font_classifier_50.pth
# Epoch 7
# -------------------------------
# Training - Epoch [7/60], Step [10/105], Loss: 0.8201
# Training - Epoch [7/60], Step [20/105], Loss: 1.7072
# Training - Epoch [7/60], Step [30/105], Loss: 1.5416
# Training - Epoch [7/60], Step [40/105], Loss: 3.5643
# Training - Epoch [7/60], Step [50/105], Loss: 1.6612
# Training - Epoch [7/60], Step [60/105], Loss: 1.6015
# Training - Epoch [7/60], Step [70/105], Loss: 2.4967
# Training - Epoch [7/60], Step [80/105], Loss: 2.5971
# Training - Epoch [7/60], Step [90/105], Loss: 0.8167
# Training - Epoch [7/60], Step [100/105], Loss: 1.9105
# Validation - Epoch [7/60], Loss: 2.7313, Accuracy: 0.2321
# Epoch 8
# -------------------------------
# Training - Epoch [8/60], Step [10/105], Loss: 1.2809
# Training - Epoch [8/60], Step [20/105], Loss: 1.2050
# Training - Epoch [8/60], Step [30/105], Loss: 1.2756
# Training - Epoch [8/60], Step [40/105], Loss: 1.3728
# Training - Epoch [8/60], Step [50/105], Loss: 2.6904
# Training - Epoch [8/60], Step [60/105], Loss: 1.9160
# Training - Epoch [8/60], Step [70/105], Loss: 1.5451
# Training - Epoch [8/60], Step [80/105], Loss: 2.4940
# Training - Epoch [8/60], Step [90/105], Loss: 2.0228
# Training - Epoch [8/60], Step [100/105], Loss: 2.3603
# Validation - Epoch [8/60], Loss: 2.0982, Accuracy: 0.4286
# Model saved as mobilenet_v3_small_font_classifier_50.pth
# Epoch 9
# -------------------------------
# Training - Epoch [9/60], Step [10/105], Loss: 1.3893
# Training - Epoch [9/60], Step [20/105], Loss: 1.7657
# Training - Epoch [9/60], Step [30/105], Loss: 0.9770
# Training - Epoch [9/60], Step [40/105], Loss: 1.9715
# Training - Epoch [9/60], Step [50/105], Loss: 0.9932
# Training - Epoch [9/60], Step [60/105], Loss: 1.4467
# Training - Epoch [9/60], Step [70/105], Loss: 1.2992
# Training - Epoch [9/60], Step [80/105], Loss: 1.3239
# Training - Epoch [9/60], Step [90/105], Loss: 1.4133
# Training - Epoch [9/60], Step [100/105], Loss: 1.0627
# Validation - Epoch [9/60], Loss: 3.3531, Accuracy: 0.2500
# Epoch 10
# -------------------------------
# Training - Epoch [10/60], Step [10/105], Loss: 1.7821
# Training - Epoch [10/60], Step [20/105], Loss: 1.8228
# Training - Epoch [10/60], Step [30/105], Loss: 1.8669
# Training - Epoch [10/60], Step [40/105], Loss: 2.1445
# Training - Epoch [10/60], Step [50/105], Loss: 0.6125
# Training - Epoch [10/60], Step [60/105], Loss: 1.5328
# Training - Epoch [10/60], Step [70/105], Loss: 1.0036
# Training - Epoch [10/60], Step [80/105], Loss: 1.0392
# Training - Epoch [10/60], Step [90/105], Loss: 1.9924
# Training - Epoch [10/60], Step [100/105], Loss: 1.3873
# Validation - Epoch [10/60], Loss: 3.6147, Accuracy: 0.2946
# Epoch 11
# -------------------------------
# Training - Epoch [11/60], Step [10/105], Loss: 1.2586
# Training - Epoch [11/60], Step [20/105], Loss: 1.8265
# Training - Epoch [11/60], Step [30/105], Loss: 1.5764
# Training - Epoch [11/60], Step [40/105], Loss: 2.6039
# Training - Epoch [11/60], Step [50/105], Loss: 1.2446
# Training - Epoch [11/60], Step [60/105], Loss: 2.0314
# Training - Epoch [11/60], Step [70/105], Loss: 1.0503
# Training - Epoch [11/60], Step [80/105], Loss: 1.7147
# Training - Epoch [11/60], Step [90/105], Loss: 2.0639
# Training - Epoch [11/60], Step [100/105], Loss: 2.5707
# Validation - Epoch [11/60], Loss: 1.5398, Accuracy: 0.5089
# Model saved as mobilenet_v3_small_font_classifier_50.pth
# Epoch 12
# -------------------------------
# Training - Epoch [12/60], Step [10/105], Loss: 0.6872
# Training - Epoch [12/60], Step [20/105], Loss: 1.6464
# Training - Epoch [12/60], Step [30/105], Loss: 1.2950
# Training - Epoch [12/60], Step [40/105], Loss: 2.1929
# Training - Epoch [12/60], Step [50/105], Loss: 1.5417
# Training - Epoch [12/60], Step [60/105], Loss: 1.7190
# Training - Epoch [12/60], Step [70/105], Loss: 2.3249
# Training - Epoch [12/60], Step [80/105], Loss: 1.3861
# Training - Epoch [12/60], Step [90/105], Loss: 0.8976
# Training - Epoch [12/60], Step [100/105], Loss: 1.1028
# Validation - Epoch [12/60], Loss: 2.2396, Accuracy: 0.3661
# Epoch 13
# -------------------------------
# Training - Epoch [13/60], Step [10/105], Loss: 1.2608
# Training - Epoch [13/60], Step [20/105], Loss: 1.4879
# Training - Epoch [13/60], Step [30/105], Loss: 0.6424
# Training - Epoch [13/60], Step [40/105], Loss: 1.0656
# Training - Epoch [13/60], Step [50/105], Loss: 0.7719
# Training - Epoch [13/60], Step [60/105], Loss: 2.8481
# Training - Epoch [13/60], Step [70/105], Loss: 2.1994
# Training - Epoch [13/60], Step [80/105], Loss: 1.7399
# Training - Epoch [13/60], Step [90/105], Loss: 0.8166
# Training - Epoch [13/60], Step [100/105], Loss: 0.8477
# Validation - Epoch [13/60], Loss: 2.4642, Accuracy: 0.3571
# Epoch 14
# -------------------------------
# Training - Epoch [14/60], Step [10/105], Loss: 0.5843
# Training - Epoch [14/60], Step [20/105], Loss: 1.4173
# Training - Epoch [14/60], Step [30/105], Loss: 1.4863
# Training - Epoch [14/60], Step [40/105], Loss: 1.4084
# Training - Epoch [14/60], Step [50/105], Loss: 1.8587
# Training - Epoch [14/60], Step [60/105], Loss: 1.0568
# Training - Epoch [14/60], Step [70/105], Loss: 1.2250
# Training - Epoch [14/60], Step [80/105], Loss: 1.3900
# Training - Epoch [14/60], Step [90/105], Loss: 1.7686
# Training - Epoch [14/60], Step [100/105], Loss: 1.2519
# Validation - Epoch [14/60], Loss: 2.4408, Accuracy: 0.3214
# Epoch 15
# -------------------------------
# Training - Epoch [15/60], Step [10/105], Loss: 0.8635
# Training - Epoch [15/60], Step [20/105], Loss: 1.7512
# Training - Epoch [15/60], Step [30/105], Loss: 0.2508
# Training - Epoch [15/60], Step [40/105], Loss: 1.0205
# Training - Epoch [15/60], Step [50/105], Loss: 0.5864
# Training - Epoch [15/60], Step [60/105], Loss: 1.5822
# Training - Epoch [15/60], Step [70/105], Loss: 0.9313
# Training - Epoch [15/60], Step [80/105], Loss: 0.8111
# Training - Epoch [15/60], Step [90/105], Loss: 1.1674
# Training - Epoch [15/60], Step [100/105], Loss: 1.4576
# Validation - Epoch [15/60], Loss: 2.4268, Accuracy: 0.4196
# Epoch 16
# -------------------------------
# Training - Epoch [16/60], Step [10/105], Loss: 0.7256
# Training - Epoch [16/60], Step [20/105], Loss: 1.6740
# Training - Epoch [16/60], Step [30/105], Loss: 1.9158
# Training - Epoch [16/60], Step [40/105], Loss: 2.0446
# Training - Epoch [16/60], Step [50/105], Loss: 1.4221
# Training - Epoch [16/60], Step [60/105], Loss: 1.2842
# Training - Epoch [16/60], Step [70/105], Loss: 0.9787
# Training - Epoch [16/60], Step [80/105], Loss: 0.8664
# Training - Epoch [16/60], Step [90/105], Loss: 1.4714
# Training - Epoch [16/60], Step [100/105], Loss: 0.4460
# Validation - Epoch [16/60], Loss: 2.6407, Accuracy: 0.3214
# Epoch 17
# -------------------------------
# Training - Epoch [17/60], Step [10/105], Loss: 1.1166
# Training - Epoch [17/60], Step [20/105], Loss: 1.1890
# Training - Epoch [17/60], Step [30/105], Loss: 0.6600
# Training - Epoch [17/60], Step [40/105], Loss: 1.2559
# Training - Epoch [17/60], Step [50/105], Loss: 0.2994
# Training - Epoch [17/60], Step [60/105], Loss: 1.0750
# Training - Epoch [17/60], Step [70/105], Loss: 0.5972
# Training - Epoch [17/60], Step [80/105], Loss: 0.9431
# Training - Epoch [17/60], Step [90/105], Loss: 0.9002
# Training - Epoch [17/60], Step [100/105], Loss: 0.2439
# Validation - Epoch [17/60], Loss: 3.9955, Accuracy: 0.2946
# Epoch 18
# -------------------------------
# Training - Epoch [18/60], Step [10/105], Loss: 1.2968
# Training - Epoch [18/60], Step [20/105], Loss: 0.4637
# Training - Epoch [18/60], Step [30/105], Loss: 1.0998
# Training - Epoch [18/60], Step [40/105], Loss: 0.6802
# Training - Epoch [18/60], Step [50/105], Loss: 0.5414
# Training - Epoch [18/60], Step [60/105], Loss: 0.8891
# Training - Epoch [18/60], Step [70/105], Loss: 1.3364
# Training - Epoch [18/60], Step [80/105], Loss: 0.9050
# Training - Epoch [18/60], Step [90/105], Loss: 2.0423
# Training - Epoch [18/60], Step [100/105], Loss: 1.4862
# Validation - Epoch [18/60], Loss: 2.0948, Accuracy: 0.4107
# Epoch 19
# -------------------------------
# Training - Epoch [19/60], Step [10/105], Loss: 0.7587
# Training - Epoch [19/60], Step [20/105], Loss: 0.6722
# Training - Epoch [19/60], Step [30/105], Loss: 0.0536
# Training - Epoch [19/60], Step [40/105], Loss: 1.1467
# Training - Epoch [19/60], Step [50/105], Loss: 0.6537
# Training - Epoch [19/60], Step [60/105], Loss: 1.5621
# Training - Epoch [19/60], Step [70/105], Loss: 0.6204
# Training - Epoch [19/60], Step [80/105], Loss: 1.0940
# Training - Epoch [19/60], Step [90/105], Loss: 1.6809
# Training - Epoch [19/60], Step [100/105], Loss: 3.1414
# Validation - Epoch [19/60], Loss: 2.8428, Accuracy: 0.3214
# Epoch 20
# -------------------------------
# Training - Epoch [20/60], Step [10/105], Loss: 1.6520
# Training - Epoch [20/60], Step [20/105], Loss: 0.5538
# Training - Epoch [20/60], Step [30/105], Loss: 1.6203
# Training - Epoch [20/60], Step [40/105], Loss: 1.3777
# Training - Epoch [20/60], Step [50/105], Loss: 0.4375
# Training - Epoch [20/60], Step [60/105], Loss: 1.3188
# Training - Epoch [20/60], Step [70/105], Loss: 1.8951
# Training - Epoch [20/60], Step [80/105], Loss: 0.6920
# Training - Epoch [20/60], Step [90/105], Loss: 0.1340
# Training - Epoch [20/60], Step [100/105], Loss: 0.8783
# Validation - Epoch [20/60], Loss: 2.3693, Accuracy: 0.3929
# Epoch 21
# -------------------------------
# Training - Epoch [21/60], Step [10/105], Loss: 1.5024
# Training - Epoch [21/60], Step [20/105], Loss: 1.1765
# Training - Epoch [21/60], Step [30/105], Loss: 1.9534
# Training - Epoch [21/60], Step [40/105], Loss: 0.4515
# Training - Epoch [21/60], Step [50/105], Loss: 0.6891
# Training - Epoch [21/60], Step [60/105], Loss: 0.4482
# Training - Epoch [21/60], Step [70/105], Loss: 0.4147
# Training - Epoch [21/60], Step [80/105], Loss: 0.2209
# Training - Epoch [21/60], Step [90/105], Loss: 0.5940
# Training - Epoch [21/60], Step [100/105], Loss: 0.4766
# Validation - Epoch [21/60], Loss: 2.1138, Accuracy: 0.4911
# Epoch 22
# -------------------------------
# Training - Epoch [22/60], Step [10/105], Loss: 0.7924
# Training - Epoch [22/60], Step [20/105], Loss: 0.2033
# Training - Epoch [22/60], Step [30/105], Loss: 0.6420
# Training - Epoch [22/60], Step [40/105], Loss: 0.6451
# Training - Epoch [22/60], Step [50/105], Loss: 0.4430
# Training - Epoch [22/60], Step [60/105], Loss: 0.8552
# Training - Epoch [22/60], Step [70/105], Loss: 1.4210
# Training - Epoch [22/60], Step [80/105], Loss: 1.4472
# Training - Epoch [22/60], Step [90/105], Loss: 1.1939
# Training - Epoch [22/60], Step [100/105], Loss: 0.9718
# Validation - Epoch [22/60], Loss: 1.3975, Accuracy: 0.5446
# Model saved as mobilenet_v3_small_font_classifier_50.pth
# Epoch 23
# -------------------------------
# Training - Epoch [23/60], Step [10/105], Loss: 1.3209
# Training - Epoch [23/60], Step [20/105], Loss: 0.7644
# Training - Epoch [23/60], Step [30/105], Loss: 0.8788
# Training - Epoch [23/60], Step [40/105], Loss: 1.2665
# Training - Epoch [23/60], Step [50/105], Loss: 1.1012
# Training - Epoch [23/60], Step [60/105], Loss: 1.5625
# Training - Epoch [23/60], Step [70/105], Loss: 0.5805
# Training - Epoch [23/60], Step [80/105], Loss: 0.2574
# Training - Epoch [23/60], Step [90/105], Loss: 0.0706
# Training - Epoch [23/60], Step [100/105], Loss: 0.3038
# Validation - Epoch [23/60], Loss: 1.5727, Accuracy: 0.5446
# Epoch 24
# -------------------------------
# Training - Epoch [24/60], Step [10/105], Loss: 0.4527
# Training - Epoch [24/60], Step [20/105], Loss: 0.5193
# Training - Epoch [24/60], Step [30/105], Loss: 0.4416
# Training - Epoch [24/60], Step [40/105], Loss: 1.7036
# Training - Epoch [24/60], Step [50/105], Loss: 0.3241
# Training - Epoch [24/60], Step [60/105], Loss: 0.2934
# Training - Epoch [24/60], Step [70/105], Loss: 0.3393
# Training - Epoch [24/60], Step [80/105], Loss: 0.3559
# Training - Epoch [24/60], Step [90/105], Loss: 0.3855
# Training - Epoch [24/60], Step [100/105], Loss: 0.8410
# Validation - Epoch [24/60], Loss: 1.9023, Accuracy: 0.4911
# Epoch 25
# -------------------------------
# Training - Epoch [25/60], Step [10/105], Loss: 0.4773
# Training - Epoch [25/60], Step [20/105], Loss: 0.3272
# Training - Epoch [25/60], Step [30/105], Loss: 0.7466
# Training - Epoch [25/60], Step [40/105], Loss: 0.9342
# Training - Epoch [25/60], Step [50/105], Loss: 0.7743
# Training - Epoch [25/60], Step [60/105], Loss: 1.1373
# Training - Epoch [25/60], Step [70/105], Loss: 0.8653
# Training - Epoch [25/60], Step [80/105], Loss: 0.2722
# Training - Epoch [25/60], Step [90/105], Loss: 0.1476
# Training - Epoch [25/60], Step [100/105], Loss: 0.4036
# Validation - Epoch [25/60], Loss: 2.1278, Accuracy: 0.5357
# Epoch 26
# -------------------------------
# Training - Epoch [26/60], Step [10/105], Loss: 1.3737
# Training - Epoch [26/60], Step [20/105], Loss: 1.6155
# Training - Epoch [26/60], Step [30/105], Loss: 1.6031
# Training - Epoch [26/60], Step [40/105], Loss: 0.5545
# Training - Epoch [26/60], Step [50/105], Loss: 0.5450
# Training - Epoch [26/60], Step [60/105], Loss: 0.3873
# Training - Epoch [26/60], Step [70/105], Loss: 0.1412
# Training - Epoch [26/60], Step [80/105], Loss: 1.0388
# Training - Epoch [26/60], Step [90/105], Loss: 1.1841
# Training - Epoch [26/60], Step [100/105], Loss: 0.3225
# Validation - Epoch [26/60], Loss: 1.7581, Accuracy: 0.5179
# Epoch 27
# -------------------------------
# Training - Epoch [27/60], Step [10/105], Loss: 0.3274
# Training - Epoch [27/60], Step [20/105], Loss: 0.2803
# Training - Epoch [27/60], Step [30/105], Loss: 0.4669
# Training - Epoch [27/60], Step [40/105], Loss: 1.8842
# Training - Epoch [27/60], Step [50/105], Loss: 0.9628
# Training - Epoch [27/60], Step [60/105], Loss: 0.9931
# Training - Epoch [27/60], Step [70/105], Loss: 1.3331
# Training - Epoch [27/60], Step [80/105], Loss: 0.8688
# Training - Epoch [27/60], Step [90/105], Loss: 0.8668
# Training - Epoch [27/60], Step [100/105], Loss: 0.4109
# Validation - Epoch [27/60], Loss: 1.9467, Accuracy: 0.5268
# Epoch 28
# -------------------------------
# Training - Epoch [28/60], Step [10/105], Loss: 0.4068
# Training - Epoch [28/60], Step [20/105], Loss: 0.2702
# Training - Epoch [28/60], Step [30/105], Loss: 1.0966
# Training - Epoch [28/60], Step [40/105], Loss: 1.5541
# Training - Epoch [28/60], Step [50/105], Loss: 0.6105
# Training - Epoch [28/60], Step [60/105], Loss: 0.3182
# Training - Epoch [28/60], Step [70/105], Loss: 0.5656
# Training - Epoch [28/60], Step [80/105], Loss: 0.6081
# Training - Epoch [28/60], Step [90/105], Loss: 1.2281
# Training - Epoch [28/60], Step [100/105], Loss: 0.5966
# Validation - Epoch [28/60], Loss: 1.4415, Accuracy: 0.6429
# Epoch 29
# -------------------------------
# Training - Epoch [29/60], Step [10/105], Loss: 0.2202
# Training - Epoch [29/60], Step [20/105], Loss: 0.3856
# Training - Epoch [29/60], Step [30/105], Loss: 1.7203
# Training - Epoch [29/60], Step [40/105], Loss: 0.1074
# Training - Epoch [29/60], Step [50/105], Loss: 1.1041
# Training - Epoch [29/60], Step [60/105], Loss: 0.3626
# Training - Epoch [29/60], Step [70/105], Loss: 0.4316
# Training - Epoch [29/60], Step [80/105], Loss: 0.1592
# Training - Epoch [29/60], Step [90/105], Loss: 1.0017
# Training - Epoch [29/60], Step [100/105], Loss: 0.0755
# Validation - Epoch [29/60], Loss: 1.6336, Accuracy: 0.6250
# Epoch 30
# -------------------------------
# Training - Epoch [30/60], Step [10/105], Loss: 0.0162
# Training - Epoch [30/60], Step [20/105], Loss: 0.7722
# Training - Epoch [30/60], Step [30/105], Loss: 0.0278
# Training - Epoch [30/60], Step [40/105], Loss: 3.7951
# Training - Epoch [30/60], Step [50/105], Loss: 0.2893
# Training - Epoch [30/60], Step [60/105], Loss: 0.6205
# Training - Epoch [30/60], Step [70/105], Loss: 0.1189
# Training - Epoch [30/60], Step [80/105], Loss: 1.1407
# Training - Epoch [30/60], Step [90/105], Loss: 0.0708
# Training - Epoch [30/60], Step [100/105], Loss: 1.2566
# Validation - Epoch [30/60], Loss: 2.0599, Accuracy: 0.5089
# Epoch 31
# -------------------------------
# Training - Epoch [31/60], Step [10/105], Loss: 0.8530
# Training - Epoch [31/60], Step [20/105], Loss: 0.0764
# Training - Epoch [31/60], Step [30/105], Loss: 0.6576
# Training - Epoch [31/60], Step [40/105], Loss: 1.3618
# Training - Epoch [31/60], Step [50/105], Loss: 0.1646
# Training - Epoch [31/60], Step [60/105], Loss: 1.1546
# Training - Epoch [31/60], Step [70/105], Loss: 0.5035
# Training - Epoch [31/60], Step [80/105], Loss: 0.2076
# Training - Epoch [31/60], Step [90/105], Loss: 1.1616
# Training - Epoch [31/60], Step [100/105], Loss: 0.1449
# Validation - Epoch [31/60], Loss: 2.5329, Accuracy: 0.4643
# Epoch 32
# -------------------------------
# Training - Epoch [32/60], Step [10/105], Loss: 0.7935
# Training - Epoch [32/60], Step [20/105], Loss: 0.3682
# Training - Epoch [32/60], Step [30/105], Loss: 0.0936
# Training - Epoch [32/60], Step [40/105], Loss: 0.9177
# Training - Epoch [32/60], Step [50/105], Loss: 0.0550
# Training - Epoch [32/60], Step [60/105], Loss: 0.5501
# Training - Epoch [32/60], Step [70/105], Loss: 0.0326
# Training - Epoch [32/60], Step [80/105], Loss: 0.5079
# Training - Epoch [32/60], Step [90/105], Loss: 0.4485
# Training - Epoch [32/60], Step [100/105], Loss: 0.0729
# Validation - Epoch [32/60], Loss: 3.0802, Accuracy: 0.4643
# Epoch 33
# -------------------------------
# Training - Epoch [33/60], Step [10/105], Loss: 0.7914
# Training - Epoch [33/60], Step [20/105], Loss: 0.5149
# Training - Epoch [33/60], Step [30/105], Loss: 0.4410
# Training - Epoch [33/60], Step [40/105], Loss: 0.1094
# Training - Epoch [33/60], Step [50/105], Loss: 0.2191
# Training - Epoch [33/60], Step [60/105], Loss: 0.3408
# Training - Epoch [33/60], Step [70/105], Loss: 0.8919
# Training - Epoch [33/60], Step [80/105], Loss: 1.4154
# Training - Epoch [33/60], Step [90/105], Loss: 0.8652
# Training - Epoch [33/60], Step [100/105], Loss: 0.4706
# Validation - Epoch [33/60], Loss: 4.7976, Accuracy: 0.3304
# Epoch 34
# -------------------------------
# Training - Epoch [34/60], Step [10/105], Loss: 0.0461
# Training - Epoch [34/60], Step [20/105], Loss: 0.2920
# Training - Epoch [34/60], Step [30/105], Loss: 1.1391
# Training - Epoch [34/60], Step [40/105], Loss: 0.0251
# Training - Epoch [34/60], Step [50/105], Loss: 0.6014
# Training - Epoch [34/60], Step [60/105], Loss: 0.4019
# Training - Epoch [34/60], Step [70/105], Loss: 0.1583
# Training - Epoch [34/60], Step [80/105], Loss: 0.5288
# Training - Epoch [34/60], Step [90/105], Loss: 0.2731
# Training - Epoch [34/60], Step [100/105], Loss: 0.0563
# Validation - Epoch [34/60], Loss: 2.4763, Accuracy: 0.5000
# Epoch 35
# -------------------------------
# Training - Epoch [35/60], Step [10/105], Loss: 0.1737
# Training - Epoch [35/60], Step [20/105], Loss: 0.1087
# Training - Epoch [35/60], Step [30/105], Loss: 1.5750
# Training - Epoch [35/60], Step [40/105], Loss: 0.6164
# Training - Epoch [35/60], Step [50/105], Loss: 0.0649
# Training - Epoch [35/60], Step [60/105], Loss: 0.2882
# Training - Epoch [35/60], Step [70/105], Loss: 0.7450
# Training - Epoch [35/60], Step [80/105], Loss: 2.2709
# Training - Epoch [35/60], Step [90/105], Loss: 2.1739
# Training - Epoch [35/60], Step [100/105], Loss: 0.3868
# Validation - Epoch [35/60], Loss: 1.6676, Accuracy: 0.6696
# Epoch 36
# -------------------------------
# Training - Epoch [36/60], Step [10/105], Loss: 0.0764
# Training - Epoch [36/60], Step [20/105], Loss: 0.1432
# Training - Epoch [36/60], Step [30/105], Loss: 0.4909
# Training - Epoch [36/60], Step [40/105], Loss: 0.9331
# Training - Epoch [36/60], Step [50/105], Loss: 0.8835
# Training - Epoch [36/60], Step [60/105], Loss: 0.2899
# Training - Epoch [36/60], Step [70/105], Loss: 0.0574
# Training - Epoch [36/60], Step [80/105], Loss: 0.6308
# Training - Epoch [36/60], Step [90/105], Loss: 0.0842
# Training - Epoch [36/60], Step [100/105], Loss: 0.2620
# Validation - Epoch [36/60], Loss: 2.6245, Accuracy: 0.4286
# Epoch 37
# -------------------------------
# Training - Epoch [37/60], Step [10/105], Loss: 0.8451
# Training - Epoch [37/60], Step [20/105], Loss: 2.3847
# Training - Epoch [37/60], Step [30/105], Loss: 0.0016
# Training - Epoch [37/60], Step [40/105], Loss: 0.2043
# Training - Epoch [37/60], Step [50/105], Loss: 0.5237
# Training - Epoch [37/60], Step [60/105], Loss: 0.0616
# Training - Epoch [37/60], Step [70/105], Loss: 0.3055
# Training - Epoch [37/60], Step [80/105], Loss: 1.1180
# Training - Epoch [37/60], Step [90/105], Loss: 0.0076
# Training - Epoch [37/60], Step [100/105], Loss: 1.3928
# Validation - Epoch [37/60], Loss: 1.8261, Accuracy: 0.5625
# Epoch 38
# -------------------------------
# Training - Epoch [38/60], Step [10/105], Loss: 2.1758
# Training - Epoch [38/60], Step [20/105], Loss: 0.2876
# Training - Epoch [38/60], Step [30/105], Loss: 0.3969
# Training - Epoch [38/60], Step [40/105], Loss: 0.0884
# Training - Epoch [38/60], Step [50/105], Loss: 0.1825
# Training - Epoch [38/60], Step [60/105], Loss: 2.3375
# Training - Epoch [38/60], Step [70/105], Loss: 1.1934
# Training - Epoch [38/60], Step [80/105], Loss: 0.0541
# Training - Epoch [38/60], Step [90/105], Loss: 0.2653
# Training - Epoch [38/60], Step [100/105], Loss: 0.3316
# Validation - Epoch [38/60], Loss: 1.6114, Accuracy: 0.5982
# Epoch 39
# -------------------------------
# Training - Epoch [39/60], Step [10/105], Loss: 0.1412
# Training - Epoch [39/60], Step [20/105], Loss: 0.5390
# Training - Epoch [39/60], Step [30/105], Loss: 0.0127
# Training - Epoch [39/60], Step [40/105], Loss: 0.3098
# Training - Epoch [39/60], Step [50/105], Loss: 0.0797
# Training - Epoch [39/60], Step [60/105], Loss: 0.5740
# Training - Epoch [39/60], Step [70/105], Loss: 0.1581
# Training - Epoch [39/60], Step [80/105], Loss: 0.5401
# Training - Epoch [39/60], Step [90/105], Loss: 0.0266
# Training - Epoch [39/60], Step [100/105], Loss: 0.0299
# Validation - Epoch [39/60], Loss: 1.8634, Accuracy: 0.5982
# Epoch 40
# -------------------------------
# Training - Epoch [40/60], Step [10/105], Loss: 0.2560
# Training - Epoch [40/60], Step [20/105], Loss: 0.2469
# Training - Epoch [40/60], Step [30/105], Loss: 0.0836
# Training - Epoch [40/60], Step [40/105], Loss: 0.9883
# Training - Epoch [40/60], Step [50/105], Loss: 0.1616
# Training - Epoch [40/60], Step [60/105], Loss: 0.7328
# Training - Epoch [40/60], Step [70/105], Loss: 0.0223
# Training - Epoch [40/60], Step [80/105], Loss: 0.3496
# Training - Epoch [40/60], Step [90/105], Loss: 0.0330
# Training - Epoch [40/60], Step [100/105], Loss: 0.5113
# Validation - Epoch [40/60], Loss: 1.9181, Accuracy: 0.5357
# Epoch 41
# -------------------------------
# Training - Epoch [41/60], Step [10/105], Loss: 0.0337
# Training - Epoch [41/60], Step [20/105], Loss: 0.1516
# Training - Epoch [41/60], Step [30/105], Loss: 0.8514
# Training - Epoch [41/60], Step [40/105], Loss: 0.9802
# Training - Epoch [41/60], Step [50/105], Loss: 0.3485
# Training - Epoch [41/60], Step [60/105], Loss: 0.0293
# Training - Epoch [41/60], Step [70/105], Loss: 0.6133
# Training - Epoch [41/60], Step [80/105], Loss: 0.6255
# Training - Epoch [41/60], Step [90/105], Loss: 0.6109
# Training - Epoch [41/60], Step [100/105], Loss: 0.1822
# Validation - Epoch [41/60], Loss: 2.2062, Accuracy: 0.5268
# Epoch 42
# -------------------------------
# Training - Epoch [42/60], Step [10/105], Loss: 0.0302
# Training - Epoch [42/60], Step [20/105], Loss: 0.9400
# Training - Epoch [42/60], Step [30/105], Loss: 0.2609
# Training - Epoch [42/60], Step [40/105], Loss: 0.2917
# Training - Epoch [42/60], Step [50/105], Loss: 0.0229
# Training - Epoch [42/60], Step [60/105], Loss: 0.4009
# Training - Epoch [42/60], Step [70/105], Loss: 0.0239
# Training - Epoch [42/60], Step [80/105], Loss: 0.0491
# Training - Epoch [42/60], Step [90/105], Loss: 0.2991
# Training - Epoch [42/60], Step [100/105], Loss: 0.1593
# Validation - Epoch [42/60], Loss: 2.5228, Accuracy: 0.5804
# Epoch 43
# -------------------------------
# Training - Epoch [43/60], Step [10/105], Loss: 0.0184
# Training - Epoch [43/60], Step [20/105], Loss: 0.0073
# Training - Epoch [43/60], Step [30/105], Loss: 0.0425
# Training - Epoch [43/60], Step [40/105], Loss: 0.6503
# Training - Epoch [43/60], Step [50/105], Loss: 0.6671
# Training - Epoch [43/60], Step [60/105], Loss: 0.5112
# Training - Epoch [43/60], Step [70/105], Loss: 0.3948
# Training - Epoch [43/60], Step [80/105], Loss: 0.2567
# Training - Epoch [43/60], Step [90/105], Loss: 0.9996
# Training - Epoch [43/60], Step [100/105], Loss: 0.5925
# Validation - Epoch [43/60], Loss: 2.5997, Accuracy: 0.5268
# Epoch 44
# -------------------------------
# Training - Epoch [44/60], Step [10/105], Loss: 1.8047
# Training - Epoch [44/60], Step [20/105], Loss: 0.4139
# Training - Epoch [44/60], Step [30/105], Loss: 0.8366
# Training - Epoch [44/60], Step [40/105], Loss: 0.7595
# Training - Epoch [44/60], Step [50/105], Loss: 0.0017
# Training - Epoch [44/60], Step [60/105], Loss: 0.1210
# Training - Epoch [44/60], Step [70/105], Loss: 0.0127
# Training - Epoch [44/60], Step [80/105], Loss: 0.7940
# Training - Epoch [44/60], Step [90/105], Loss: 0.1843
# Training - Epoch [44/60], Step [100/105], Loss: 1.2583
# Validation - Epoch [44/60], Loss: 2.0587, Accuracy: 0.5357
# Epoch 45
# -------------------------------
# Training - Epoch [45/60], Step [10/105], Loss: 0.6849
# Training - Epoch [45/60], Step [20/105], Loss: 0.1886
# Training - Epoch [45/60], Step [30/105], Loss: 0.1064
# Training - Epoch [45/60], Step [40/105], Loss: 0.6156
# Training - Epoch [45/60], Step [50/105], Loss: 0.3156
# Training - Epoch [45/60], Step [60/105], Loss: 0.1761
# Training - Epoch [45/60], Step [70/105], Loss: 0.0379
# Training - Epoch [45/60], Step [80/105], Loss: 0.0376
# Training - Epoch [45/60], Step [90/105], Loss: 0.1085
# Training - Epoch [45/60], Step [100/105], Loss: 0.2786
# Validation - Epoch [45/60], Loss: 2.3471, Accuracy: 0.5446
# Epoch 46
# -------------------------------
# Training - Epoch [46/60], Step [10/105], Loss: 0.4986
# Training - Epoch [46/60], Step [20/105], Loss: 0.4089
# Training - Epoch [46/60], Step [30/105], Loss: 0.1562
# Training - Epoch [46/60], Step [40/105], Loss: 0.0148
# Training - Epoch [46/60], Step [50/105], Loss: 0.0510
# Training - Epoch [46/60], Step [60/105], Loss: 0.3753
# Training - Epoch [46/60], Step [70/105], Loss: 0.0816
# Training - Epoch [46/60], Step [80/105], Loss: 0.2232
# Training - Epoch [46/60], Step [90/105], Loss: 0.6806
# Training - Epoch [46/60], Step [100/105], Loss: 0.3583
# Validation - Epoch [46/60], Loss: 2.1104, Accuracy: 0.5982
# Epoch 47
# -------------------------------
# Training - Epoch [47/60], Step [10/105], Loss: 0.1651
# Training - Epoch [47/60], Step [20/105], Loss: 0.1289
# Training - Epoch [47/60], Step [30/105], Loss: 0.3503
# Training - Epoch [47/60], Step [40/105], Loss: 0.5490
# Training - Epoch [47/60], Step [50/105], Loss: 0.5507
# Training - Epoch [47/60], Step [60/105], Loss: 0.9493
# Training - Epoch [47/60], Step [70/105], Loss: 0.1638
# Training - Epoch [47/60], Step [80/105], Loss: 0.3725
# Training - Epoch [47/60], Step [90/105], Loss: 0.3046
# Training - Epoch [47/60], Step [100/105], Loss: 0.5944
# Validation - Epoch [47/60], Loss: 1.9412, Accuracy: 0.6696
# Epoch 48
# -------------------------------
# Training - Epoch [48/60], Step [10/105], Loss: 0.1148
# Training - Epoch [48/60], Step [20/105], Loss: 0.2389
# Training - Epoch [48/60], Step [30/105], Loss: 0.0328
# Training - Epoch [48/60], Step [40/105], Loss: 0.0985
# Training - Epoch [48/60], Step [50/105], Loss: 0.3195
# Training - Epoch [48/60], Step [60/105], Loss: 0.3222
# Training - Epoch [48/60], Step [70/105], Loss: 0.0329
# Training - Epoch [48/60], Step [80/105], Loss: 0.0953
# Training - Epoch [48/60], Step [90/105], Loss: 0.1896
# Training - Epoch [48/60], Step [100/105], Loss: 0.5757
# Validation - Epoch [48/60], Loss: 1.9992, Accuracy: 0.5625
# Epoch 49
# -------------------------------
# Training - Epoch [49/60], Step [10/105], Loss: 0.0141
# Training - Epoch [49/60], Step [20/105], Loss: 0.5541
# Training - Epoch [49/60], Step [30/105], Loss: 0.1733
# Training - Epoch [49/60], Step [40/105], Loss: 0.0364
# Training - Epoch [49/60], Step [50/105], Loss: 0.0395
# Training - Epoch [49/60], Step [60/105], Loss: 0.0247
# Training - Epoch [49/60], Step [70/105], Loss: 1.4530
# Training - Epoch [49/60], Step [80/105], Loss: 0.0433
# Training - Epoch [49/60], Step [90/105], Loss: 0.2817
# Training - Epoch [49/60], Step [100/105], Loss: 0.3917
# Validation - Epoch [49/60], Loss: 2.8100, Accuracy: 0.5268
# Epoch 50
# -------------------------------
# Training - Epoch [50/60], Step [10/105], Loss: 0.1527
# Training - Epoch [50/60], Step [20/105], Loss: 0.3295
# Training - Epoch [50/60], Step [30/105], Loss: 0.0593
# Training - Epoch [50/60], Step [40/105], Loss: 0.0209
# Training - Epoch [50/60], Step [50/105], Loss: 0.1644
# Training - Epoch [50/60], Step [60/105], Loss: 0.3091
# Training - Epoch [50/60], Step [70/105], Loss: 0.8758
# Training - Epoch [50/60], Step [80/105], Loss: 0.0151
# Training - Epoch [50/60], Step [90/105], Loss: 0.3879
# Training - Epoch [50/60], Step [100/105], Loss: 0.0188
# Validation - Epoch [50/60], Loss: 2.4892, Accuracy: 0.5804
# Epoch 51
# -------------------------------
# Training - Epoch [51/60], Step [10/105], Loss: 0.7938
# Training - Epoch [51/60], Step [20/105], Loss: 0.0061
# Training - Epoch [51/60], Step [30/105], Loss: 0.2668
# Training - Epoch [51/60], Step [40/105], Loss: 0.3984
# Training - Epoch [51/60], Step [50/105], Loss: 2.3800
# Training - Epoch [51/60], Step [60/105], Loss: 1.4493
# Training - Epoch [51/60], Step [70/105], Loss: 0.9235
# Training - Epoch [51/60], Step [80/105], Loss: 0.0098
# Training - Epoch [51/60], Step [90/105], Loss: 0.0208
# Training - Epoch [51/60], Step [100/105], Loss: 0.0206
# Validation - Epoch [51/60], Loss: 1.9502, Accuracy: 0.5714
# Epoch 52
# -------------------------------
# Training - Epoch [52/60], Step [10/105], Loss: 1.2234
# Training - Epoch [52/60], Step [20/105], Loss: 0.5344
# Training - Epoch [52/60], Step [30/105], Loss: 0.1083
# Training - Epoch [52/60], Step [40/105], Loss: 0.0002
# Training - Epoch [52/60], Step [50/105], Loss: 0.3020
# Training - Epoch [52/60], Step [60/105], Loss: 0.6144
# Training - Epoch [52/60], Step [70/105], Loss: 0.1663
# Training - Epoch [52/60], Step [80/105], Loss: 0.2055
# Training - Epoch [52/60], Step [90/105], Loss: 0.1171
# Training - Epoch [52/60], Step [100/105], Loss: 2.0240
# Validation - Epoch [52/60], Loss: 1.9390, Accuracy: 0.5982
# Epoch 53
# -------------------------------
# Training - Epoch [53/60], Step [10/105], Loss: 0.1849
# Training - Epoch [53/60], Step [20/105], Loss: 0.4344
# Training - Epoch [53/60], Step [30/105], Loss: 0.2558
# Training - Epoch [53/60], Step [40/105], Loss: 0.0234
# Training - Epoch [53/60], Step [50/105], Loss: 0.1450
# Training - Epoch [53/60], Step [60/105], Loss: 0.0242
# Training - Epoch [53/60], Step [70/105], Loss: 0.0877
# Training - Epoch [53/60], Step [80/105], Loss: 0.0306
# Training - Epoch [53/60], Step [90/105], Loss: 0.0129
# Training - Epoch [53/60], Step [100/105], Loss: 0.2094
# Validation - Epoch [53/60], Loss: 2.3770, Accuracy: 0.5714
# Epoch 54
# -------------------------------
# Training - Epoch [54/60], Step [10/105], Loss: 0.0171
# Training - Epoch [54/60], Step [20/105], Loss: 0.0603
# Training - Epoch [54/60], Step [30/105], Loss: 0.0581
# Training - Epoch [54/60], Step [40/105], Loss: 0.0013
# Training - Epoch [54/60], Step [50/105], Loss: 0.0079
# Training - Epoch [54/60], Step [60/105], Loss: 0.0065
# Training - Epoch [54/60], Step [70/105], Loss: 0.3465
# Training - Epoch [54/60], Step [80/105], Loss: 0.0061
# Training - Epoch [54/60], Step [90/105], Loss: 0.2291
# Training - Epoch [54/60], Step [100/105], Loss: 0.0163
# Validation - Epoch [54/60], Loss: 2.9296, Accuracy: 0.5089
# Epoch 55
# -------------------------------
# Training - Epoch [55/60], Step [10/105], Loss: 0.4207
# Training - Epoch [55/60], Step [20/105], Loss: 0.2519
# Training - Epoch [55/60], Step [30/105], Loss: 0.7842
# Training - Epoch [55/60], Step [40/105], Loss: 0.0021
# Training - Epoch [55/60], Step [50/105], Loss: 0.0249
# Training - Epoch [55/60], Step [60/105], Loss: 0.0114
# Training - Epoch [55/60], Step [70/105], Loss: 0.0307
# Training - Epoch [55/60], Step [80/105], Loss: 0.0837
# Training - Epoch [55/60], Step [90/105], Loss: 0.7014
# Training - Epoch [55/60], Step [100/105], Loss: 0.0980
# Validation - Epoch [55/60], Loss: 2.1230, Accuracy: 0.5804
# Epoch 56
# -------------------------------
# Training - Epoch [56/60], Step [10/105], Loss: 0.5962
# Training - Epoch [56/60], Step [20/105], Loss: 0.0043
# Training - Epoch [56/60], Step [30/105], Loss: 0.0962
# Training - Epoch [56/60], Step [40/105], Loss: 0.0855
# Training - Epoch [56/60], Step [50/105], Loss: 0.3676
# Training - Epoch [56/60], Step [60/105], Loss: 0.0282
# Training - Epoch [56/60], Step [70/105], Loss: 0.6165
# Training - Epoch [56/60], Step [80/105], Loss: 0.0062
# Training - Epoch [56/60], Step [90/105], Loss: 0.0077
# Training - Epoch [56/60], Step [100/105], Loss: 0.0208
# Validation - Epoch [56/60], Loss: 6.6676, Accuracy: 0.3125
# Epoch 57
# -------------------------------
# Training - Epoch [57/60], Step [10/105], Loss: 0.0025
# Training - Epoch [57/60], Step [20/105], Loss: 0.1245
# Training - Epoch [57/60], Step [30/105], Loss: 0.3098
# Training - Epoch [57/60], Step [40/105], Loss: 0.1226
# Training - Epoch [57/60], Step [50/105], Loss: 0.0186
# Training - Epoch [57/60], Step [60/105], Loss: 0.0010
# Training - Epoch [57/60], Step [70/105], Loss: 0.0012
# Training - Epoch [57/60], Step [80/105], Loss: 0.0029
# Training - Epoch [57/60], Step [90/105], Loss: 0.0135
# Training - Epoch [57/60], Step [100/105], Loss: 0.0182
# Validation - Epoch [57/60], Loss: 2.6615, Accuracy: 0.5000
# Epoch 58
# -------------------------------
# Training - Epoch [58/60], Step [10/105], Loss: 1.0205
# Training - Epoch [58/60], Step [20/105], Loss: 2.1010
# Training - Epoch [58/60], Step [30/105], Loss: 0.0489
# Training - Epoch [58/60], Step [40/105], Loss: 0.0312
# Training - Epoch [58/60], Step [50/105], Loss: 0.0224
# Training - Epoch [58/60], Step [60/105], Loss: 0.0260
# Training - Epoch [58/60], Step [70/105], Loss: 0.4345
# Training - Epoch [58/60], Step [80/105], Loss: 0.1183
# Training - Epoch [58/60], Step [90/105], Loss: 0.0200
# Training - Epoch [58/60], Step [100/105], Loss: 0.0183
# Validation - Epoch [58/60], Loss: 2.7868, Accuracy: 0.5804
# Epoch 59
# -------------------------------
# Training - Epoch [59/60], Step [10/105], Loss: 0.1101
# Training - Epoch [59/60], Step [20/105], Loss: 0.0136
# Training - Epoch [59/60], Step [30/105], Loss: 0.0040
# Training - Epoch [59/60], Step [40/105], Loss: 0.0783
# Training - Epoch [59/60], Step [50/105], Loss: 0.0025
# Training - Epoch [59/60], Step [60/105], Loss: 0.0069
# Training - Epoch [59/60], Step [70/105], Loss: 0.0569
# Training - Epoch [59/60], Step [80/105], Loss: 0.0071
# Training - Epoch [59/60], Step [90/105], Loss: 0.0036
# Training - Epoch [59/60], Step [100/105], Loss: 0.0046
# Validation - Epoch [59/60], Loss: 2.9491, Accuracy: 0.5714
# Epoch 60
# -------------------------------
# Training - Epoch [60/60], Step [10/105], Loss: 0.0463
# Training - Epoch [60/60], Step [20/105], Loss: 0.0027
# Training - Epoch [60/60], Step [30/105], Loss: 0.0006
# Training - Epoch [60/60], Step [40/105], Loss: 0.0284
# Training - Epoch [60/60], Step [50/105], Loss: 0.0013
# Training - Epoch [60/60], Step [60/105], Loss: 0.3944
# Training - Epoch [60/60], Step [70/105], Loss: 0.0203
# Training - Epoch [60/60], Step [80/105], Loss: 0.0096
# Training - Epoch [60/60], Step [90/105], Loss: 0.0039
# Training - Epoch [60/60], Step [100/105], Loss: 0.0079
# Validation - Epoch [60/60], Loss: 4.7875, Accuracy: 0.4643

# %% [markdown]
# # Plot the training and validation metrics

# %%
# Plotting
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), train_losses, label='Training Loss')
plt.plot(range(1, num_epochs + 1), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), train_accuracies, label='Training Accuracy')
plt.plot(range(1, num_epochs + 1), val_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

print('Finished Training')

# Print the time taken for training
print(f'Time taken for training: {end_time - start_time:.2f} seconds')
## Print medium time per epoch
print(f'Medium time per epoch: {(end_time - start_time)/num_epochs:.2f} seconds')
# Out:
# Finished Training
# Time taken for training: 666.71 seconds
# Medium time per epoch: 11.11 seconds

# %% [markdown]
# # Evaluate the model

# %% [markdown]
# ## Load the model

# %%
# Load the model
model_path = f'../../models/{scope}/{model_name}_font_classifier_{type}.pth'
model = models.__dict__[model_name](weights=None)
model.load_state_dict(torch.load(model_path))
model = model.to(device)
print(f'Model loaded from {model_path}')
# Out:
# Model loaded from ../../models/DatasetSize/mobilenet_v3_small_font_classifier_50.pth

# %% [markdown]
# ## Evaluate the model
# Evaluate the model using the test set. We will compute the accuracy, precision, recall, F1-score, confusion matrix, and ROC curve.

# %%
# Set the model to evaluation mode
model.eval()

# Initialize lists for true labels and predicted labels
true_labels = []
predicted_labels = []

# Disable gradient computation for evaluation
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        # Perform inference
        outputs = model(images)
        
        # Compute predicted labels
        _, predicted = torch.max(outputs.data, 1)
        
        # Append true and predicted labels to lists
        true_labels.extend(labels.cpu().numpy())
        predicted_labels.extend(predicted.cpu().numpy())

# Convert lists to numpy arrays
true_labels = np.array(true_labels)
predicted_labels = np.array(predicted_labels)

# %% [markdown]
# ## Compute metrics
# ### Accuracy

# %%
accuracy = accuracy_score(true_labels, predicted_labels)
print('Accuracy: {:.2f}%'.format(100 * accuracy))
# Out:
# Accuracy: 59.29%

# %% [markdown]
# ### Precision

# %%
precision = precision_score(true_labels, predicted_labels, average='weighted')
print('Precision: {:.2f}'.format(precision))
# Out:
# Precision: 0.70

# %% [markdown]
# ### Recall

# %%
recall = recall_score(true_labels, predicted_labels, average='weighted')
print('Recall: {:.2f}'.format(recall))
# Out:
# Recall: 0.59

# %% [markdown]
# ### F1-score

# %%
f1 = f1_score(true_labels, predicted_labels, average='weighted')
print('F1-score: {:.2f}'.format(f1))
# Out:
# F1-score: 0.61

# %% [markdown]
# ### Confusion matrix

# %%
conf_matrix = confusion_matrix(true_labels, predicted_labels)
print(f'Confusion Matrix:')
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='g', cbar=False, xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Confusion Matrix:

# %% [markdown]
# ### ROC curve

# %%
# Binarize the true labels
true_labels_binarized = label_binarize(true_labels, classes=range(len(class_names)))

# Binarize the predicted labels
predicted_labels_binarized = label_binarize(predicted_labels, classes=range(len(class_names)))

# Compute the ROC curve
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(len(class_names)):
    fpr[i], tpr[i], _ = roc_curve(true_labels_binarized[:, i], predicted_labels_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
# Plot the ROC curve
plt.figure()
for i in range(len(class_names)):
    plt.plot(fpr[i], tpr[i], lw=2, label=f'ROC curve for class {class_names[i]} (area = {roc_auc[i]:0.2f})')
plt.plot([0, 1], [0, 1], 'k--', lw=2)
